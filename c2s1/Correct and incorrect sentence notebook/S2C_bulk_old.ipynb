# %%
import spacy
import sys
import nltk
import regex as re

# %%
# !pip install regex
# Out:
# Collecting regex
#   Using cached regex-2020.2.20-cp37-cp37m-win_amd64.whl (271 kB)
# Installing collected packages: regex
# Successfully installed regex-2020.2.20

# %% [markdown]
# ### Segregating the sentence into Subject predicate and object

# %%
def get_it_all_spacy(sen):
#     print(sen)
    doc = nlp(sen)
    count=0
    cclst = list()
    sublst = list()
    verblst = list()
    subjlst = list()
    objlst = list()
    for token in doc:
        count+=1
        ## Checks for the speech tag of word having a coordinating conjunction or "For" or "So"
        if "CC" in token.pos_ or " for " == " "+str(token)+" " or  " so " == " "+str(token)+" ":
            cclst.append([count,str(token)])
    if len(cclst)==0:
        ## Append the coordinating conjunction along with its relative position
        cclst.append([count,"CCab"])
    count = 0
    for token in doc:
        count+=1
        if "VERB" in token.pos_ or "AUX" in token.pos_:
            ## Checks for speech tag of word having verb
            verblst.append([count,str(token)])
    if len(verblst)==0:
        ## Append the verb along with its relative position
        verblst.append([count,"VBab"])
    count = 0
    for token in doc:
        count+=1
        if "NOUN" in token.pos_ or "PRON" in token.pos_ or "PROPN" in token.pos_:
            sublst.append([count,str(token)])
    if len(sublst)==0:
        ## Append the noun along with its relative position
        sublst.append([count,"SBab"])
#     print("Subject = ",sublst)
#     print("Verb = ",verblst)
    k=0
    r=0
    i=0;
    flag = 0
    ccoccur = cclst[i][0]
    verboccur = verblst[k][0]   
    try:
        ## Use the verb of the relative position with relative noun.
        ## If the verb occurs before the noun then append as object else append as subject.
        ## but this is not necessarily the case everytime.. 
        ## I like playing basketball and I like playing football. 
        ## In ^ above case -- "I" that occurs before the verb "like" is taken as subject. 
        ## but for the same case "basketball" since it occurs after "like" becomes object.
        ## this is the simple case.. in the same example.. if the verb is still "like" of the 
        ## first clause, then "I" of the second clause is made object, hence it is necessary to locate
        ## the correct verb with respect to which the noun is taken. 
        ## the following code deals with locating the verb
        while verboccur< sublst[r][0]: # Checks for auxillary verbal conditions
            k+=1
            verboccur = verblst[k][0]
    except: # If no auxillary verb
        k-=1
        verboccur = verblst[k][0]
    try:    
        flag = 0
        while (1):
            j = sublst[r]
#             print("Accessing , ",j[1],verblst[k][1])
            ccoccur = cclst[i][0]
            verboccur = verblst[k][0]
            if j[0]<=verboccur: # Checks whether subject occurs before or after the verb.. and accordingly appends.
                subjlst.append([j[0],j[1]])
            if j[0]>verboccur:
                objlst.append([j[0],j[1]])
            r+=1 # Iterating to next noun, 
            try:
                j = sublst[r] # If next noun exists
            except:
                j = sublst[r-1] # If next noun doesnt exist
            if j[0]>=verboccur: # Locate the next verb if the next noun exists
                try:
                    while(j[0]>verboccur):
                        k+=1
                        verboccur = verblst[k][0]
                except: # reflect back to previous verb if the next verb was not successfully located
                    k-=1
                    verboccur = verblst[k][0]
#                 print(k,verblst[k])
            if(flag==1): # Terminating condition check
                try:
                    objlst.append([sublst[r][0],sublst[r][1]]) # If noun exists then last noun is object
                except:
#                     print("no last object")
                    pass
#                 print("broke")
                break;

            if(sublst[r][0]>=ccoccur): # Creating terminating condition... 
                try:
                    i+=1    
                    ccoccur = cclst[i][0] # If no forward coordinating conjunction, then no more breaks required.
                except:
                    i-=1
                    flag = 1; # Hence check one last time for clause and then break
#             print(ccoccur)

    except:
#         print(sys.exc_info()[0])
        pass
#     print(subjlst,objlst)
#     print(verblst)
#     print(cclst)
    return (subjlst,objlst,verblst,cclst)
#Data preparation completed

# %% [markdown]
# ### Rule 1 segregation
# ##### -- Breaking conjunction

# %%
# Rule 1 segregation
# Breaking conjunction
def rule_1(sen):
    subjlst,objlst,verblst,cclst = get_it_all_spacy(sen)
    doc = nlp(sen)
#     print(subjlst,objlst,verblst,cclst)
    broke = list()
    i =0
    j=0
    count = len(cclst)
    if cclst[0][1] == "CCab" : # If no coordinating conjunction--already simple sentence
        return([],[],["Already Simple --- ",sen],1) # 1 == sends check to main to say "not a compound sentence"
    else:
        try:
            cap = cclst[i][1] # Locate the next coordinating conjunction and break the sentence further
            while (1):
#                 print(str(doc[j]))
    #             print(cap)
                cap = cclst[i][1]
                if str(cap).strip()==str(doc[j]):
    #                 print(str(doc[j]))
                    broke.append(j) # Append the location of the clauses to the broke list.
                    count-=1
                    if count!=0: # Check for multiple conjunctions
                        i+=1
                    else:
                        break
                j+=1
        except:
#             print(sys.exc_info()[0])
            pass
        # The following code appends the clause to the fin list depending on the broke locations.
        broke.append(len(str(doc))) 
#         print(broke)
        fin = list()
        fin.append(str(doc[0:broke[0]]))
        try:
            for i in range(len(broke)):
                fin.append(str(doc[broke[i]+1:broke[i+1]]))
        except:
#             print(sys.exec_info()[0])
            pass
    final= list()
    for i in fin:
    #     print(i)
        stri = str()    
        for j in i:
            stri+= j
        final.append(stri) # converting each word of the token to a string and appending the string
    broke = final
#     print(broke)
    for i in broke:
        if i == "": # if broke has any non existent string then remove.
            broke.remove(i)
    return (subjlst,objlst,broke,0) # Returns check as 0 to say "Compound sentence"

# %% [markdown]
# ### Rule 2 or Rule 3 check
# #### -- accordingly decompose

# %%
def rule_2_3(empsubjlst,allavail,onlyobjlst,onlysubjlst):
    count = 0
    try:
        # The following works on rule 2 or 3 check plus performs 
        # the rules on the lists provided it passes rule 1
        while len(empsubjlst)!=0: # If no subject then perform reverse rule 2
            # The following performs rule3
            extract = len(allavail)-1 # Gets the most recently used string to append to the subject. 
            subj3lst,obj3lst,verb3lst,cc3lst = get_it_all_spacy(allavail[extract][1])
            for i in empsubjlst:
                finstr= subj3lst[0][1]+" "+i[1] # appends the string to the subject
                count=subj3lst[0][0]+1
                allavail.append([count,finstr]) # appends the string to the list of simple sentences
#                 print(finstr)
                empsubjlst.remove(i) # removes the string from the incomplete sentence list
        while len(onlyobjlst)!=0: 
            # For normal rule2 usecase
            # extract finds the most recently used string
            # appends to that string the object
            # removes the incomplete clause and adds the complete simple sentence to the 
            # list of simple sentences.
            extract = len(allavail)-1
#             print(extract,len(allavail))
            subj3lst,obj3lst,verb3lst,cc3lst = get_it_all_spacy(allavail[extract][1])
            objlen=len(obj3lst)-1
            prestr = allavail[extract][1].replace(obj3lst[objlen][1],"")
        #     print(prestr)
            for i in onlyobjlst:
                finstr = prestr+" "+i[1]
                count=allavail[extract][0]+1
                allavail.append([count,finstr])
#                 print(finstr)
                onlyobjlst.remove(i)
        while len(onlysubjlst)!=0:
            # When only subject exists:
            # This is the reverse rule2 case:
            # gets the next complete sentence between which the subject exists.
            # appends this subject to the predicate and object of the corresponding found sentence
            # appends the final simple complete sentence to list of complete sentences
            # removes the incomplete sentence/ subject from the onlysubjlist.
            for i in onlysubjlst:
                extract = i[0]+1
                for j in range(len(allavail)):
                    if allavail[j][0] == extract:
                        extract = j
                        break
#                 print(extract)
                subj3lst,obj3lst,verb3lst,cc3lst = get_it_all_spacy(allavail[extract][1])
                subjlen = len(subj3lst)-1
                prestr = allavail[extract][1].replace(subj3lst[subjlen][1],"")
                finstr = i[1]+" "+prestr
                count=allavail[extract][0]+1
                allavail.append([count,finstr])
#                 print(finstr)
                onlysubjlst.remove(i)
        return (allavail)
    except:
#         print(sys.exc_info())
        pass

# %% [markdown]
# ### Main function.. performs rule 1 and checks whether rule1 is sufficient else performs rule2 or 3 check

# %%
# Rule 1 check
def main(sen,fw):
    subjlst,objlst,broke,check = rule_1(sen)
#     print("\n------\n")
    ## Check denotes whether the sentence is already simple or not.
    if(check):
        fw.write("Sentence = "+sen+"\n")
        for i in broke:
            fw.write("\t"+i+"\n")
        fw.write("\n----\n")
        return
    ## The following lists are used to segregate rule 1 complete/incomplete..
    ## if incomplete then prepares data for rule2 and 3
    allavail = list()
    empsubjlst = list()
    empobjlst = list()
    empverblst = list()
    onlyobjlst = list()
    onlysubjlst = list()
    count=0;
    total = len(broke)
    for i in broke:
        ## Checks all sentences of the conjunction broke sentences. 
        subj=1;
        verb=1;
        obj=1;
        count+=1
        ## The following line gets the broken sentence's predicate subject and object.
        subj2lst,obj2lst,verb2lst,cc2lst = get_it_all_spacy(i.strip())
        print("New stripped sentence = ",subj2lst,obj2lst,verb2lst,cc2lst)
        print("Origial sentence connotation= ",subjlst,objlst)
        ## if no subject: turn variable of subj 0 to denote.. no subject.
        if len(subj2lst)==0:
            subj=0
            if len(obj2lst)!=0:
                ## it is possible that object of the sentence may not be an object in the 
                ## original sentence before breaking by conjunction instead could be a subject
                ## in such case it finds the whether subject or object of original sentence
                ## and makes subj variable 1 and obj variable 0
                if any(obj2lst[0][1] in ls for ls in subjlst):
                    print("Check",obj2lst[0][1],subjlst)
                    subj=1
                    obj=0
        if len(obj2lst)==0:
            obj=0;
            ## Similarly performs similar checking for subject of the sentence and makes 
            ## necessary variables show it. 
            if len(subj2lst)!=0:
                if any(subj2lst[0][1] in ls for ls in objlst):
                    print("Check",subj2lst[0][1],objlst)
                    subj=0
                    obj=1
        ## If there is no verb in the sentence.. in case of dependent clauses. 
        if verb2lst[0][1]=="VBab":
            verb=0;
        if subj==0 and verb!=0 and obj!=0:
            ## empsubjlst is for the dependant clauses.. - rule 3
            empsubjlst.append([count,i])
        if subj==0 and verb==0 and obj!=0:
            ## onlyobjlst is for the independant clauses -- rule2
            onlyobjlst.append([count,i])
        if subj!=0 and verb!=0:
            ## allavail -- clauses that are simple and independent
            lstnew = list()
            it = i
            try:
                if verb2lst[0][0]==1:
                    lstnew = i.split()
                    temp = lstnew[0]
                    lstnew[0]=lstnew[1]
                    lstnew[1] = temp
                    i=""
                    for word in lstnew:
                        i+=word+ " "
                print(i)
            except:
                i = it;
            allavail.append([count,i])
        if subj!=0 and verb==0 and obj==0:
            ## For reverse rule 2 case where only subject exists in the dependant clause.
            onlysubjlst.append([count,i])
        print(empsubjlst,onlysubjlst,onlyobjlst,allavail)
    # Check for case in Rule2 or Rule3:
    if len(broke)==len(allavail):
        fw.write("Sentence = "+sen+"\n")
        for i in allavail:
            print(re.sub(' +', ' ',i[1]).strip())
            fw.write("\t"+re.sub(' +', ' ',i[1]).strip()+"\n") 
        fw.write("\n-----\n")
    else:
        try:
            allavail = rule_2_3(empsubjlst,allavail,onlyobjlst,onlysubjlst)
            fw.write("Sentence = "+sen+"\n")
            for i in allavail:
                print(re.sub(r'\b(.+)\s+\1\b', r'\1', re.sub(' +', ' ',i[1]).strip()))
                fw.write("\t"+re.sub(r'\b(.+)\s+\1\b', r'\1', re.sub(' +', ' ',i[1]).strip())+"\n")
            fw.write("\n-----\n")
        except:
            fw.write("Sentence = "+sen+"\n")
            print(sys.exc_info()[0])
            fw.write("\tAlready Simple\n")
            fw.write("\n-----\n")

# %% [markdown]
# #### Sepereate the sentences that have bare semi colon

# %%
def sep_semi(input):
    rw = open(input)
    fw = open("tempoutput.txt","w")
    for line in rw:
        line = re.sub("[^\P{P}\.;]|","",str(nlp(line)))
        fw.write(line+"\n")
#         r = line.split(". ")
#         for i in r:
#             if i==" ":
#                 r.remove(i)
# #         fw.write(line+"\n")
#         if(len(r)!=0):
#             for i in r:
#                 fw.write(i+"\n")
    rw.close()
    fw.close()
    rw = open("tempoutput.txt")
    lst = list()
    for line in rw:
        lst.append(line.split(";"))
    rw.close()
    rw = open("tempoutput.txt","w")
    for i in lst:
        if(len(i)>1):
            for sep in i:
                rw.write(sep.strip())
                rw.write("\n")
        else:
            rw.write(i[0])
#                 print(sep.strip())
    fw.close()
    rw.close()

# %% [markdown]
# ### Function that coordinates with the main

# %%
nlp = spacy.load("en_core_web_sm")
# Splits sentences by the semi colon
# also removes punctuations
sep_semi(input("Enter the location of the input file: "))
rw = open("tempoutput.txt")
fw = open("output.txt","w")
for i in rw:
    main(i,fw)   
rw.close()
fw.close()
# Out:
# Enter the location of the input file: input3.txt
# New stripped sentence =  [[3, 'dog']] [[7, 'prizes']] [[4, 'has'], [5, 'won']] [[7, 'CCab']]
# Origial sentence connotation=  [[3, 'dog'], [7, 'prizes'], [9, 'he']] [[12, 't']]
# The black dog has won many prizes
# [] [] [] [[1, 'The black dog has won many prizes']]
# New stripped sentence =  [[1, 'he'], [4, 't']] [[7, 'tricks']] [[5, 'know']] [[8, 'CCab']]
# Origial sentence connotation=  [[3, 'dog'], [7, 'prizes'], [9, 'he']] [[12, 't']]
# he doesnâ€™t know many tricks.
#
# [] [] [] [[1, 'The black dog has won many prizes'], [2, 'he doesnâ€™t know many tricks.\n']]
# The black dog has won many prizes
# he doesnâ€™t know many tricks.
# New stripped sentence =  [[1, 'She']] [[4, 'cat'], [5, 'run'], [7, 'front'], [9, 'her']] [[2, 'saw']] [[9, 'CCab']]
# Origial sentence connotation=  [[1, 'She'], [4, 'cat'], [5, 'run'], [7, 'front'], [9, 'her'], [11, 'she']] []
# She saw a cat run in front of her
# [] [] [] [[1, 'She saw a cat run in front of her']]
# New stripped sentence =  [[1, 'she']] [] [[2, 'fell'], [5, 'rollerskating']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'She'], [4, 'cat'], [5, 'run'], [7, 'front'], [9, 'her'], [11, 'she']] []
# she fell down while rollerskating.
#
# [] [] [] [[1, 'She saw a cat run in front of her'], [2, 'she fell down while rollerskating.\n']]
# She saw a cat run in front of her
# she fell down while rollerskating.
# New stripped sentence =  [] [[9, 'shower'], [13, 'space']] [[3, 'was']] [[13, 'CCab']]
# Origial sentence connotation=  [[9, 'shower'], [13, 'space'], [19, 'crew']] [[34, 'meteors']]
# Check shower [[9, 'shower'], [13, 'space'], [19, 'crew']]
# There  was  a  meteor  shower  in  space
# [] [] [] [[1, 'There  was  a  meteor  shower  in  space  ']]
# New stripped sentence =  [[3, 'crew']] [[18, 'meteors']] [[5, 'did'], [9, 'know'], [15, 'avoid']] [[19, 'CCab']]
# Origial sentence connotation=  [[9, 'shower'], [13, 'space'], [19, 'crew']] [[34, 'meteors']]
#  the  crew  did  not  know  how  to  avoid  the meteors.
#
# [] [] [] [[1, 'There  was  a  meteor  shower  in  space  '], [2, ' the  crew  did  not  know  how  to  avoid  the meteors.\n']]
# There was a meteor shower in space
# the crew did not know how to avoid the meteors.
# New stripped sentence =  [[1, 'I']] [[6, 'baby'], [7, 'Chihuahua']] [[2, 'wanted'], [4, 'buy']] [[7, 'CCab']]
# Origial sentence connotation=  [[1, 'I'], [6, 'baby'], [7, 'Chihuahua'], [9, 'I']] [[14, 'money']]
# I wanted to buy a baby Chihuahua
# [] [] [] [[1, 'I wanted to buy a baby Chihuahua']]
# New stripped sentence =  [[1, 'I']] [[6, 'money']] [[2, 'started'], [4, 'save']] [[7, 'CCab']]
# Origial sentence connotation=  [[1, 'I'], [6, 'baby'], [7, 'Chihuahua'], [9, 'I']] [[14, 'money']]
# I started to save my money.
#
# [] [] [] [[1, 'I wanted to buy a baby Chihuahua'], [2, 'I started to save my money.\n']]
# I wanted to buy a baby Chihuahua
# I started to save my money.
# New stripped sentence =  [[1, 'Gillian']] [] [[2, 'did'], [4, 'like'], [6, 'read']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'Gillian'], [8, 'she']] [[14, 'it']]
# Gillian did not like to read
# [] [] [] [[1, 'Gillian did not like to read']]
# New stripped sentence =  [[1, 'she']] [[7, 'it']] [[2, 'was']] [[8, 'CCab']]
# Origial sentence connotation=  [[1, 'Gillian'], [8, 'she']] [[14, 'it']]
# she was not very good at it.
#
# [] [] [] [[1, 'Gillian did not like to read'], [2, 'she was not very good at it.\n']]
# Gillian did not like to read
# she was not very good at it.
# New stripped sentence =  [[1, 'Pam']] [[5, 'Wayne']] [[3, 'liked']] [[5, 'CCab']]
# Origial sentence connotation=  [[1, 'Pam'], [5, 'Wayne'], [8, 'Leena']] [[11, 'Wayne']]
# Pam  liked  Wayne
# [] [] [] [[1, 'Pam  liked  Wayne  ']]
# New stripped sentence =  [[1, 'Leena']] [[4, 'Wayne']] [[3, 'liked']] [[5, 'CCab']]
# Origial sentence connotation=  [[1, 'Pam'], [5, 'Wayne'], [8, 'Leena']] [[11, 'Wayne']]
# Leena also liked Wayne.
#
# [] [] [] [[1, 'Pam  liked  Wayne  '], [2, 'Leena also liked Wayne.\n']]
# Pam liked Wayne
# Leena also liked Wayne.
# New stripped sentence =  [[1, 'You']] [[6, 'baby']] [[2, 'could'], [3, 'cry']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'You'], [6, 'baby'], [8, 'you']] [[12, 'room']]
# You could cry like a baby
# [] [] [] [[1, 'You could cry like a baby']]
# New stripped sentence =  [[1, 'you']] [[5, 'room'], [8, 'adult']] [[2, 'can'], [3, 'clean']] [[9, 'CCab']]
# Origial sentence connotation=  [[1, 'You'], [6, 'baby'], [8, 'you']] [[12, 'room']]
# you can clean your room like an adult.
#
# [] [] [] [[1, 'You could cry like a baby'], [2, 'you can clean your room like an adult.\n']]
# You could cry like a baby
# you can clean your room like an adult.
# New stripped sentence =  [[1, 'She'], [4, 't']] [[9, 'Jill']] [[5, 'want'], [7, 'play']] [[9, 'CCab']]
# Origial sentence connotation=  [[1, 'She'], [4, 't'], [9, 'Jill'], [11, 'she']] [[14, 't']]
# She didnâ€™t want to play with Jill
# [] [] [] [[1, 'She didnâ€™t want to play with Jill']]
# New stripped sentence =  [[1, 'she'], [4, 't']] [[9, 'Tim']] [[5, 'want'], [7, 'play']] [[10, 'CCab']]
# Origial sentence connotation=  [[1, 'She'], [4, 't'], [9, 'Jill'], [11, 'she']] [[14, 't']]
# she didnâ€™t want to play with Tim.
#
# [] [] [] [[1, 'She didnâ€™t want to play with Jill'], [2, 'she didnâ€™t want to play with Tim.\n']]
# She didnâ€™t want to play with Jill
# she didnâ€™t want to play with Tim.
# New stripped sentence =  [[1, 'Arleenâ€']] [[9, 'boy']] [[4, 'could'], [6, 'play']] [[9, 'CCab']]
# Origial sentence connotation=  [[1, 'Arleenâ€'], [9, 'boy'], [12, 'she']] [[17, 'boy']]
# Arleenâ€™s could not play with that boy
# [] [] [] [[1, 'Arleenâ€™s could not play with that boy']]
# New stripped sentence =  [[2, 'she']] [[7, 'boy']] [[1, 'could'], [3, 'play']] [[8, 'CCab']]
# Origial sentence connotation=  [[1, 'Arleenâ€'], [9, 'boy'], [12, 'she']] [[17, 'boy']]
# she could play with that other boy.
# [] [] [] [[1, 'Arleenâ€™s could not play with that boy'], [2, 'she could play with that other boy. ']]
# Arleenâ€™s could not play with that boy
# she could play with that other boy.
# New stripped sentence =  [[1, 'Letâ€'], [3, 's']] [[7, 'swimming'], [8, 'pool']] [[4, 'go']] [[8, 'CCab']]
# Origial sentence connotation=  [[1, 'Letâ€'], [3, 's']] [[7, 'swimming'], [8, 'pool'], [10, 'itâ€'], [12, 's']]
# Letâ€™s go to the swimming pool
# [] [] [] [[1, 'Letâ€™s go to the swimming pool']]
# New stripped sentence =  [[1, 'itâ€'], [3, 's'], [7, 'house']] [] [[8, 'VBab']] [[8, 'CCab']]
# Origial sentence connotation=  [[1, 'Letâ€'], [3, 's']] [[7, 'swimming'], [8, 'pool'], [10, 'itâ€'], [12, 's']]
# Check itâ€ [[7, 'swimming'], [8, 'pool'], [10, 'itâ€'], [12, 's']]
# [] [] [[2, 'itâ€™s hot inside the house.\n']] [[1, 'Letâ€™s go to the swimming pool']]
# Letâ€™s go to the swimming pool
# Letâ€™s go to the swimming itâ€™s hot inside the house.
# New stripped sentence =  [[1, 'I'], [4, 't']] [] [[2, 'donâ€'], [5, 'want'], [7, 'eat']] [[7, 'CCab']]
# Origial sentence connotation=  [[1, 'I'], [4, 't'], [9, 'I']] [[12, 't']]
# I donâ€™t want to eat
# [] [] [] [[1, 'I donâ€™t want to eat']]
# New stripped sentence =  [[1, 'I'], [4, 't']] [] [[2, 'donâ€'], [5, 'want'], [7, 'drink']] [[8, 'CCab']]
# Origial sentence connotation=  [[1, 'I'], [4, 't'], [9, 'I']] [[12, 't']]
# I donâ€™t want to drink.
#
# [] [] [] [[1, 'I donâ€™t want to eat'], [2, 'I donâ€™t want to drink.\n']]
# I donâ€™t want to eat
# I donâ€™t want to drink.
# New stripped sentence =  [[1, 'I']] [[7, 'company']] [[2, 'want'], [4, 'own']] [[7, 'CCab']]
# Origial sentence connotation=  [[1, 'I'], [7, 'company'], [9, 'I']] [[15, 'workers']]
# I want to own my own company
# [] [] [] [[1, 'I want to own my own company']]
# New stripped sentence =  [[1, 'I']] [[7, 'workers'], [9, 'lot'], [11, 'money']] [[2, 'want'], [4, 'pay']] [[12, 'CCab']]
# Origial sentence connotation=  [[1, 'I'], [7, 'company'], [9, 'I']] [[15, 'workers']]
# I want to pay all my workers a lot of money.
#
# [] [] [] [[1, 'I want to own my own company'], [2, 'I want to pay all my workers a lot of money.\n']]
# I want to own my own company
# I want to pay all my workers a lot of money.
# New stripped sentence =  [[1, 'I']] [[7, 'store']] [[2, 'need'], [4, 'go']] [[7, 'CCab']]
# Origial sentence connotation=  [[1, 'I'], [7, 'store'], [9, 'Iâ€']] [[11, 'm']]
# I need to go to the store
# [] [] [] [[1, 'I need to go to the store']]
# New stripped sentence =  [[1, 'Iâ€'], [3, 'm'], [4, 'feeling']] [] [[8, 'drive']] [[9, 'CCab']]
# Origial sentence connotation=  [[1, 'I'], [7, 'store'], [9, 'Iâ€']] [[11, 'm']]
# Iâ€™m feeling too sick to drive.
#
# [] [] [] [[1, 'I need to go to the store'], [2, 'Iâ€™m feeling too sick to drive.\n']]
# I need to go to the store
# Iâ€™m feeling too sick to drive.
# New stripped sentence =  [[1, 'Rabbits']] [[4, 'pets']] [[2, 'make']] [[4, 'CCab']]
# Origial sentence connotation=  [[1, 'Rabbits'], [4, 'pets'], [6, 'they'], [9, 't'], [13, 'noise'], [15, 'they']] []
# Rabbits make good pets
# [] [] [] [[1, 'Rabbits make good pets']]
# New stripped sentence =  [[1, 'they'], [4, 't']] [[8, 'noise']] [[2, 'donâ€'], [5, 'make']] [[8, 'CCab']]
# Origial sentence connotation=  [[1, 'Rabbits'], [4, 'pets'], [6, 'they'], [9, 't'], [13, 'noise'], [15, 'they']] []
# they donâ€™t make too much noise
# [] [] [] [[1, 'Rabbits make good pets'], [2, 'they donâ€™t make too much noise']]
# New stripped sentence =  [[1, 'they']] [] [[2, 'are']] [[4, 'CCab']]
# Origial sentence connotation=  [[1, 'Rabbits'], [4, 'pets'], [6, 'they'], [9, 't'], [13, 'noise'], [15, 'they']] []
# they are clean.
#
# [] [] [] [[1, 'Rabbits make good pets'], [2, 'they donâ€™t make too much noise'], [3, 'they are clean.\n']]
# Rabbits make good pets
# they donâ€™t make too much noise
# they are clean.
# New stripped sentence =  [[1, 'I']] [[7, 'circus']] [[2, 'want'], [4, 'go']] [[7, 'CCab']]
# Origial sentence connotation=  [[1, 'I'], [7, 'circus'], [9, 'I']] [[14, 'pony']]
# I want to go to the circus
# [] [] [] [[1, 'I want to go to the circus']]
# New stripped sentence =  [[1, 'I']] [[6, 'pony']] [[2, 'want'], [4, 'ride']] [[7, 'CCab']]
# Origial sentence connotation=  [[1, 'I'], [7, 'circus'], [9, 'I']] [[14, 'pony']]
# I want to ride a pony.
#
# [] [] [] [[1, 'I want to go to the circus'], [2, 'I want to ride a pony.\n']]
# I want to go to the circus
# I want to ride a pony.
# New stripped sentence =  [[1, 'I'], [4, 't']] [[7, 'homework']] [[2, 'didnâ€'], [5, 'do']] [[7, 'CCab']]
# Origial sentence connotation=  [[1, 'I'], [4, 't'], [7, 'homework'], [10, 'parents']] [[12, 'me']]
# I didnâ€™t do my homework
# [] [] [] [[1, 'I didnâ€™t do my homework']]
# New stripped sentence =  [[2, 'parents']] [[4, 'me']] [[3, 'punished']] [[5, 'CCab']]
# Origial sentence connotation=  [[1, 'I'], [4, 't'], [7, 'homework'], [10, 'parents']] [[12, 'me']]
# my parents punished me.
#
# [] [] [] [[1, 'I didnâ€™t do my homework'], [2, 'my parents punished me.\n']]
# I didnâ€™t do my homework
# my parents punished me.
# New stripped sentence =  [[1, 'I']] [[5, 'Asia']] [[2, 'have'], [4, 'visited']] [[5, 'CCab']]
# Origial sentence connotation=  [[1, 'I'], [5, 'Asia'], [8, 'I']] [[10, 'Africa']]
# I have never visited Asia
# [] [] [] [[1, 'I have never visited Asia']]
# New stripped sentence =  [[2, 'I']] [[4, 'Africa']] [[1, 'have'], [3, 'visited']] [[5, 'CCab']]
# Origial sentence connotation=  [[1, 'I'], [5, 'Asia'], [8, 'I']] [[10, 'Africa']]
# I have visited Africa.
# [] [] [] [[1, 'I have never visited Asia'], [2, 'I have visited Africa. ']]
# I have never visited Asia
# I have visited Africa.
# New stripped sentence =  [[1, 'You']] [[6, 'poster']] [[2, 'can'], [3, 'make']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'You'], [6, 'poster'], [8, 'you']] [[13, 'clay']]
# You can make a big poster
# [] [] [] [[1, 'You can make a big poster']]
# New stripped sentence =  [[1, 'you']] [[6, 'clay'], [7, 'statue']] [[2, 'can'], [3, 'make']] [[8, 'CCab']]
# Origial sentence connotation=  [[1, 'You'], [6, 'poster'], [8, 'you']] [[13, 'clay']]
# you can make a little clay statue.
#
# [] [] [] [[1, 'You can make a big poster'], [2, 'you can make a little clay statue.\n']]
# You can make a big poster
# you can make a little clay statue.
# New stripped sentence =  [[3, 'kitten']] [[5, 'me']] [[4, 'followed']] [[6, 'CCab']]
# Origial sentence connotation=  [[3, 'kitten'], [5, 'me'], [8, 'I']] [[10, 'it']]
# A small kitten followed me home
# [] [] [] [[1, 'A small kitten followed me home']]
# New stripped sentence =  [[1, 'I']] [[3, 'it'], [5, 'bowl'], [7, 'milk']] [[2, 'gave']] [[8, 'CCab']]
# Origial sentence connotation=  [[3, 'kitten'], [5, 'me'], [8, 'I']] [[10, 'it']]
# I gave it a bowl of milk.
#
# [] [] [] [[1, 'A small kitten followed me home'], [2, 'I gave it a bowl of milk.\n']]
# A small kitten followed me home
# I gave it a bowl of milk.
# New stripped sentence =  [[1, 'We']] [[6, 'woods']] [[2, 'were'], [3, 'lost']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'We'], [6, 'woods'], [9, 'brother']] [[12, 'map']]
# We were lost in the woods
# [] [] [] [[1, 'We were lost in the woods']]
# New stripped sentence =  [[2, 'brother']] [[5, 'map'], [8, 'backpack']] [[3, 'had']] [[9, 'CCab']]
# Origial sentence connotation=  [[1, 'We'], [6, 'woods'], [9, 'brother']] [[12, 'map']]
# my brother had a map in his backpack.
#
# [] [] [] [[1, 'We were lost in the woods'], [2, 'my brother had a map in his backpack.\n']]
# We were lost in the woods
# my brother had a map in his backpack.
# New stripped sentence =  [[2, 'girls']] [[5, 'animal'], [6, 'pictures']] [[3, 'were'], [4, 'painting']] [[6, 'CCab']]
# Origial sentence connotation=  [[2, 'girls'], [5, 'animal'], [6, 'pictures'], [8, 'Katrina']] [[11, 'paint']]
# The girls were painting animal pictures
# [] [] [] [[1, 'The girls were painting animal pictures']]
# New stripped sentence =  [[1, 'Katrina']] [[4, 'paint']] [[2, 'spilled']] [[5, 'CCab']]
# Origial sentence connotation=  [[2, 'girls'], [5, 'animal'], [6, 'pictures'], [8, 'Katrina']] [[11, 'paint']]
# Katrina spilled the paint.
#
# [] [] [] [[1, 'The girls were painting animal pictures'], [2, 'Katrina spilled the paint.\n']]
# The girls were painting animal pictures
# Katrina spilled the paint.
# New stripped sentence =  [[2, 'you']] [[8, 'movies']] [[1, 'Would'], [3, 'like'], [5, 'go']] [[8, 'CCab']]
# Origial sentence connotation=  [[2, 'you'], [8, 'movies'], [11, 'you']] []
# you Would like to go to the movies
# [] [] [] [[1, 'you Would like to go to the movies ']]
# New stripped sentence =  [[2, 'you']] [] [[1, 'would'], [4, 'stay']] [[5, 'CCab']]
# Origial sentence connotation=  [[2, 'you'], [8, 'movies'], [11, 'you']] []
# you would rather stay hometonight
# [] [] [] [[1, 'you Would like to go to the movies '], [2, 'you would rather stay hometonight ']]
# you Would like to go to the movies
# you would rather stay hometonight
# New stripped sentence =  [[1, 'Mr.'], [2, 'Sanchez']] [[6, 'office']] [[3, 'loved']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'Mr.'], [2, 'Sanchez'], [6, 'office'], [8, 'he']] [[13, 'view']]
# Mr. Sanchez loved his new office
# [] [] [] [[1, 'Mr. Sanchez loved his new office']]
# New stripped sentence =  [[1, 'he']] [[6, 'view']] [[2, 'did'], [4, 'like']] [[7, 'CCab']]
# Origial sentence connotation=  [[1, 'Mr.'], [2, 'Sanchez'], [6, 'office'], [8, 'he']] [[13, 'view']]
# he didnt like the view.
#
# [] [] [] [[1, 'Mr. Sanchez loved his new office'], [2, 'he didnt like the view.\n']]
# Mr. Sanchez loved his new office
# he didnt like the view.
# New stripped sentence =  [[1, 'Ivanas'], [2, 'bicycle']] [[6, 'tire']] [[3, 'had']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'Ivanas'], [2, 'bicycle'], [6, 'tire'], [8, 'she']] [[14, 'grocery']]
# Ivanas bicycle had a flat tire
# [] [] [] [[1, 'Ivanas bicycle had a flat tire']]
# New stripped sentence =  [[1, 'she']] [[7, 'grocery'], [8, 'store']] [[2, 'had'], [4, 'walk']] [[9, 'CCab']]
# Origial sentence connotation=  [[1, 'Ivanas'], [2, 'bicycle'], [6, 'tire'], [8, 'she']] [[14, 'grocery']]
# she had to walk to the grocery store.
#
# [] [] [] [[1, 'Ivanas bicycle had a flat tire'], [2, 'she had to walk to the grocery store.\n']]
# Ivanas bicycle had a flat tire
# she had to walk to the grocery store.
# New stripped sentence =  [[2, '©'], [7, 'astronaut'], [9, 'he']] [] [[3, 'wants'], [5, 'be'], [10, 'grows']] [[11, 'CCab']]
# Origial sentence connotation=  [[2, '©'], [7, 'astronaut'], [9, 'he'], [13, 'Maria']] [[17, 'nurse']]
# JosÃ© wants to be an astronaut when he grows up
# [] [] [] [[1, 'JosÃ© wants to be an astronaut when he grows up']]
# New stripped sentence =  [[1, 'Maria']] [[5, 'nurse']] [[2, 'wants'], [3, 'tobe']] [[6, 'CCab']]
# Origial sentence connotation=  [[2, '©'], [7, 'astronaut'], [9, 'he'], [13, 'Maria']] [[17, 'nurse']]
# Maria wants tobe a nurse.
#
# [] [] [] [[1, 'JosÃ© wants to be an astronaut when he grows up'], [2, 'Maria wants tobe a nurse.\n']]
# JosÃ© wants to be an astronaut when he grows up
# Maria wants tobe a nurse.
# New stripped sentence =  [[1, 'Dr.'], [2, 'Neu'], [4, 'Greg']] [[8, 'teeth'], [10, 'day']] [[3, 'told'], [6, 'floss']] [[10, 'CCab']]
# Origial sentence connotation=  [[1, 'Dr.'], [2, 'Neu'], [4, 'Greg'], [8, 'teeth'], [10, 'day'], [12, 'he']] []
# Dr. Neu told Greg to floss his teeth every day
# [] [] [] [[1, 'Dr. Neu told Greg to floss his teeth every day']]
# New stripped sentence =  [[1, 'he']] [] [[2, 'did'], [4, 'listen']] [[5, 'CCab']]
# Origial sentence connotation=  [[1, 'Dr.'], [2, 'Neu'], [4, 'Greg'], [8, 'teeth'], [10, 'day'], [12, 'he']] []
# he didnt listen.
#
# [] [] [] [[1, 'Dr. Neu told Greg to floss his teeth every day'], [2, 'he didnt listen.\n']]
# Dr. Neu told Greg to floss his teeth every day
# he didnt listen.
# New stripped sentence =  [[2, 'tigers'], [5, 'zoo']] [] [[6, 'are'], [8, 'sleeping']] [[8, 'CCab']]
# Origial sentence connotation=  [[2, 'tigers'], [5, 'zoo'], [11, 'penguins']] []
# The tigers at the zoo are always sleeping
# [] [] [] [[1, 'The tigers at the zoo are always sleeping']]
# New stripped sentence =  [[2, 'penguins']] [] [[3, 'are'], [6, 'watch']] [[7, 'CCab']]
# Origial sentence connotation=  [[2, 'tigers'], [5, 'zoo'], [11, 'penguins']] []
# the penguins are fun to watch.
#
# [] [] [] [[1, 'The tigers at the zoo are always sleeping'], [2, 'the penguins are fun to watch.\n']]
# The tigers at the zoo are always sleeping
# the penguins are fun to watch.
# New stripped sentence =  [[1, 'Tom']] [] [[2, 'arrived']] [[3, 'CCab']]
# Origial sentence connotation=  [[1, 'Tom']] [[6, 'dinner']]
# Tom arrived home
# [] [] [] [[1, 'Tom arrived home']]
# New stripped sentence =  [] [[2, 'dinner']] [[1, 'ate']] [[3, 'CCab']]
# Origial sentence connotation=  [[1, 'Tom']] [[6, 'dinner']]
# [[2, 'ate dinner.\n']] [] [] [[1, 'Tom arrived home']]
# Tom arrived home
# Tom ate dinner.
# New stripped sentence =  [[1, 'We']] [[4, 'hours']] [[2, 'studied']] [[4, 'CCab']]
# Origial sentence connotation=  [[1, 'We'], [4, 'hours'], [7, 'test'], [9, 'we']] [[13, 'it']]
# We studied many hours
# [] [] [] [[1, 'We studied many hours']]
# New stripped sentence =  [[2, 'test']] [] [[2, 'VBab']] [[2, 'CCab']]
# Origial sentence connotation=  [[1, 'We'], [4, 'hours'], [7, 'test'], [9, 'we']] [[13, 'it']]
# [] [[2, 'the test']] [] [[1, 'We studied many hours']]
# New stripped sentence =  [[1, 'we']] [[5, 'it']] [[2, 'did'], [4, 'pass']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'We'], [4, 'hours'], [7, 'test'], [9, 'we']] [[13, 'it']]
# we didnt pass it.
#
# [] [[2, 'the test']] [] [[1, 'We studied many hours'], [3, 'we didnt pass it.\n']]
# We studied many hours
# we didnt pass it.
# the test didnt pass it.
# New stripped sentence =  [[1, 'Peter']] [[9, 'car']] [[2, 'does'], [4, 'need'], [6, 'buy']] [[9, 'CCab']]
# Origial sentence connotation=  [[1, 'Peter'], [9, 'car'], [12, 'he']] [[17, 'vacation']]
# Peter doesnt need to buy a new car
# [] [] [] [[1, 'Peter doesnt need to buy a new car']]
# New stripped sentence =  [[2, 'he']] [[7, 'vacation']] [[1, 'does'], [3, 'need'], [5, 'go']] [[8, 'CCab']]
# Origial sentence connotation=  [[1, 'Peter'], [9, 'car'], [12, 'he']] [[17, 'vacation']]
# he does need to go on vacation.
# [] [] [] [[1, 'Peter doesnt need to buy a new car'], [2, 'he does need to go on vacation. ']]
# Peter doesnt need to buy a new car
# he does need to go on vacation.
# New stripped sentence =  [[1, 'Peter']] [[6, 'friend']] [[2, 'drove'], [4, 'visit']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'Peter'], [6, 'friend'], [8, 'they']] [[12, 'dinner']]
# Peter drove to visit his friend
# [] [] [] [[1, 'Peter drove to visit his friend']]
# New stripped sentence =  [[1, 'they']] [] [[2, 'went']] [[3, 'CCab']]
# Origial sentence connotation=  [[1, 'Peter'], [6, 'friend'], [8, 'they']] [[12, 'dinner']]
# they went out
# [] [] [] [[1, 'Peter drove to visit his friend'], [2, 'they went out']]
# New stripped sentence =  [[1, 'dinner']] [] [[2, 'VBab']] [[2, 'CCab']]
# Origial sentence connotation=  [[1, 'Peter'], [6, 'friend'], [8, 'they']] [[12, 'dinner']]
# Check dinner [[12, 'dinner']]
# [] [] [[3, 'dinner.\n']] [[1, 'Peter drove to visit his friend'], [2, 'they went out']]
# <class 'TypeError'>
# New stripped sentence =  [[1, 'Mary'], [3, 'she']] [[7, 'school']] [[2, 'thinks'], [4, 'should'], [5, 'go']] [[7, 'CCab']]
# Origial sentence connotation=  [[1, 'Mary'], [3, 'she'], [7, 'school'], [9, 'she']] [[13, 'qualifications'], [17, 'profession']]
# Mary thinks she should go to school
# [] [] [] [[1, 'Mary thinks she should go to school']]
# New stripped sentence =  [[1, 'she']] [[5, 'qualifications']] [[2, 'wants'], [4, 'get']] [[5, 'CCab']]
# Origial sentence connotation=  [[1, 'Mary'], [3, 'she'], [7, 'school'], [9, 'she']] [[13, 'qualifications'], [17, 'profession']]
# she wants to get qualifications
# [] [] [] [[1, 'Mary thinks she should go to school'], [2, 'she wants to get qualifications']]
# New stripped sentence =  [[3, 'profession']] [] [[4, 'VBab']] [[4, 'CCab']]
# Origial sentence connotation=  [[1, 'Mary'], [3, 'she'], [7, 'school'], [9, 'she']] [[13, 'qualifications'], [17, 'profession']]
# Check profession [[13, 'qualifications'], [17, 'profession']]
# [] [] [[3, 'a new profession.\n']] [[1, 'Mary thinks she should go to school'], [2, 'she wants to get qualifications']]
# Mary thinks she should go to school
# she wants to get qualifications
# she wants to get a new profession.
# New stripped sentence =  [[1, 'Alan']] [[4, 'lot'], [6, 'money'], [9, 'business']] [[2, 'invested']] [[9, 'CCab']]
# Origial sentence connotation=  [[1, 'Alan'], [4, 'lot'], [6, 'money'], [9, 'business'], [12, 'business']] []
# Alan invested a lot of money in the business
# [] [] [] [[1, 'Alan invested a lot of money in the business']]
# New stripped sentence =  [[2, 'business']] [] [[3, 'went']] [[5, 'CCab']]
# Origial sentence connotation=  [[1, 'Alan'], [4, 'lot'], [6, 'money'], [9, 'business'], [12, 'business']] []
# the business went bankrupt.
#
# [] [] [] [[1, 'Alan invested a lot of money in the business'], [2, 'the business went bankrupt.\n']]
# Alan invested a lot of money in the business
# the business went bankrupt.
# New stripped sentence =  [[1, 'Doug']] [[6, 'homework'], [7, 'assignment']] [[2, 'did'], [4, 'understand']] [[7, 'CCab']]
# Origial sentence connotation=  [[1, 'Doug'], [6, 'homework'], [7, 'assignment'], [9, 'he']] [[12, 'teacher'], [14, 'help']]
# Doug didnt understand the homework assignment
# [] [] [] [[1, 'Doug didnt understand the homework assignment']]
# New stripped sentence =  [[1, 'he']] [[4, 'teacher']] [[2, 'asked']] [[4, 'CCab']]
# Origial sentence connotation=  [[1, 'Doug'], [6, 'homework'], [7, 'assignment'], [9, 'he']] [[12, 'teacher'], [14, 'help']]
# he asked the teacher
# [] [] [] [[1, 'Doug didnt understand the homework assignment'], [2, 'he asked the teacher']]
# New stripped sentence =  [] [[2, 'SBab']] [[1, 'help']] [[2, 'CCab']]
# Origial sentence connotation=  [[1, 'Doug'], [6, 'homework'], [7, 'assignment'], [9, 'he']] [[12, 'teacher'], [14, 'help']]
# [[3, 'help.\n']] [] [] [[1, 'Doug didnt understand the homework assignment'], [2, 'he asked the teacher']]
# Doug didnt understand the homework assignment
# he asked the teacher
# he help.
# New stripped sentence =  [[2, 'students']] [] [[3, 'did'], [5, 'prepare']] [[5, 'CCab']]
# Origial sentence connotation=  [[2, 'students'], [8, 'test'], [11, 'they']] [[16, 'test']]
# The students didnt prepare
# [] [] [] [[1, 'The students didnt prepare']]
# New stripped sentence =  [[2, 'test']] [] [[2, 'VBab']] [[2, 'CCab']]
# Origial sentence connotation=  [[2, 'students'], [8, 'test'], [11, 'they']] [[16, 'test']]
# Check test [[16, 'test']]
# [] [] [[2, 'the test']] [[1, 'The students didnt prepare']]
# New stripped sentence =  [[2, 'they'], [7, 'test']] [] [[1, 'did'], [3, 'realize'], [8, 'was']] [[9, 'CCab']]
# Origial sentence connotation=  [[2, 'students'], [8, 'test'], [11, 'they']] [[16, 'test']]
# they did realize how important the test was.
# [] [] [[2, 'the test']] [[1, 'The students didnt prepare'], [3, 'they did realize how important the test was. ']]
# <class 'TypeError'>
# New stripped sentence =  [[1, 'Susan'], [3, 'she']] [] [[2, 'thinks'], [4, 'should'], [5, 'stay']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'Susan'], [3, 'she'], [10, 'she']] [[14, 'vacation']]
# Susan thinks she should stay home
# [] [] [] [[1, 'Susan thinks she should stay home']]
# New stripped sentence =  [[1, 'SBab']] [] [[1, 'relax']] [[1, 'CCab']]
# Origial sentence connotation=  [[1, 'Susan'], [3, 'she'], [10, 'she']] [[14, 'vacation']]
# [] [] [] [[1, 'Susan thinks she should stay home'], [2, 'relax']]
# New stripped sentence =  [[1, 'she']] [[5, 'vacation']] [[2, 'should'], [3, 'go']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'Susan'], [3, 'she'], [10, 'she']] [[14, 'vacation']]
# she should go on vacation.
#
# [] [] [] [[1, 'Susan thinks she should stay home'], [2, 'relax'], [3, 'she should go on vacation.\n']]
# Susan thinks she should stay home
# relax
# she should go on vacation.
# New stripped sentence =  [[2, 'doctors']] [[6, 'xrays']] [[3, 'looked']] [[6, 'CCab']]
# Origial sentence connotation=  [[2, 'doctors'], [6, 'xrays'], [8, 'they']] [[14, 'patient']]
# The doctors looked at the xrays
# [] [] [] [[1, 'The doctors looked at the xrays']]
# New stripped sentence =  [[1, 'they']] [[7, 'patient']] [[2, 'decided'], [4, 'operate']] [[8, 'CCab']]
# Origial sentence connotation=  [[2, 'doctors'], [6, 'xrays'], [8, 'they']] [[14, 'patient']]
# they decided to operate on the patient.
#
# [] [] [] [[1, 'The doctors looked at the xrays'], [2, 'they decided to operate on the patient.\n']]
# The doctors looked at the xrays
# they decided to operate on the patient.
# New stripped sentence =  [[1, 'We']] [[6, 'town']] [[2, 'went']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'We'], [6, 'town'], [8, 'we']] []
# We went out on the town
# [] [] [] [[1, 'We went out on the town']]
# New stripped sentence =  [[1, 'we']] [] [[2, 'came']] [[5, 'CCab']]
# Origial sentence connotation=  [[1, 'We'], [6, 'town'], [8, 'we']] []
# we came home late.
#
# [] [] [] [[1, 'We went out on the town'], [2, 'we came home late.\n']]
# We went out on the town
# we came home late.
# New stripped sentence =  [[1, 'Jack'], [4, 'London']] [[8, 'Uncle']] [[2, 'flew'], [6, 'visit']] [[8, 'CCab']]
# Origial sentence connotation=  [[1, 'Jack'], [4, 'London'], [8, 'Uncle']] [[13, 'National'], [14, 'Museum']]
# Jack flew to London to visit his Uncle
# [] [] [] [[1, 'Jack flew to London to visit his Uncle']]
# New stripped sentence =  [] [[4, 'National'], [5, 'Museum']] [[2, 'visit']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'Jack'], [4, 'London'], [8, 'Uncle']] [[13, 'National'], [14, 'Museum']]
# [[2, 'to visit the National Museum.\n']] [] [] [[1, 'Jack flew to London to visit his Uncle']]
# Jack flew to London to visit his Uncle
# Jack to visit the National Museum.
# New stripped sentence =  [[1, 'It']] [] [[2, 'is']] [[3, 'CCab']]
# Origial sentence connotation=  [[1, 'It'], [5, 'it']] []
# It is sunny
# [] [] [] [[1, 'It is sunny']]
# New stripped sentence =  [[1, 'it']] [] [[2, 'is']] [[5, 'CCab']]
# Origial sentence connotation=  [[1, 'It'], [5, 'it']] []
# it is very cold.
#
# [] [] [] [[1, 'It is sunny'], [2, 'it is very cold.\n']]
# It is sunny
# it is very cold.
# New stripped sentence =  [[1, 'Henry']] [] [[2, 'studied']] [[4, 'CCab']]
# Origial sentence connotation=  [[1, 'Henry'], [7, 'test']] [[12, 'marks']]
# Henry studied very hard
# [] [] [] [[1, 'Henry studied very hard']]
# New stripped sentence =  [[2, 'test']] [] [[2, 'VBab']] [[2, 'CCab']]
# Origial sentence connotation=  [[1, 'Henry'], [7, 'test']] [[12, 'marks']]
# [] [[2, 'the test']] [] [[1, 'Henry studied very hard']]
# New stripped sentence =  [] [[4, 'marks']] [[1, 'passed']] [[5, 'CCab']]
# Origial sentence connotation=  [[1, 'Henry'], [7, 'test']] [[12, 'marks']]
# [[3, 'passed with high marks.\n']] [[2, 'the test']] [] [[1, 'Henry studied very hard']]
# <class 'TypeError'>
# New stripped sentence =  [[1, 'I']] [[6, 'tennis'], [7, 'today']] [[2, 'would'], [3, 'like'], [5, 'play']] [[7, 'CCab']]
# Origial sentence connotation=  [[1, 'I'], [6, 'tennis'], [7, 'today'], [9, 'I']] [[14, 'golf']]
# I would like to play tennis today
# [] [] [] [[1, 'I would like to play tennis today']]
# New stripped sentence =  [[1, 'I']] [[6, 'golf']] [[2, 'would'], [3, 'like'], [5, 'play']] [[7, 'CCab']]
# Origial sentence connotation=  [[1, 'I'], [6, 'tennis'], [7, 'today'], [9, 'I']] [[14, 'golf']]
# I would like to play golf.
#
# [] [] [] [[1, 'I would like to play tennis today'], [2, 'I would like to play golf.\n']]
# I would like to play tennis today
# I would like to play golf.
# New stripped sentence =  [[1, 'We']] [[4, 'food']] [[2, 'needed']] [[4, 'CCab']]
# Origial sentence connotation=  [[1, 'We'], [4, 'food'], [7, 'week'], [9, 'we']] [[13, 'supermarket']]
# We needed some food
# [] [] [] [[1, 'We needed some food']]
# New stripped sentence =  [[2, 'week']] [] [[2, 'VBab']] [[2, 'CCab']]
# Origial sentence connotation=  [[1, 'We'], [4, 'food'], [7, 'week'], [9, 'we']] [[13, 'supermarket']]
# [] [[2, 'the week']] [] [[1, 'We needed some food']]
# New stripped sentence =  [[1, 'we']] [[5, 'supermarket']] [[2, 'went']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'We'], [4, 'food'], [7, 'week'], [9, 'we']] [[13, 'supermarket']]
# we went to the supermarket.
#
# [] [[2, 'the week']] [] [[1, 'We needed some food'], [3, 'we went to the supermarket.\n']]
# We needed some food
# we went to the supermarket.
# the week nt to the supermarket.
# New stripped sentence =  [[1, 'Tom']] [[4, 'teacher']] [[2, 'asked']] [[4, 'CCab']]
# Origial sentence connotation=  [[1, 'Tom'], [4, 'teacher'], [6, 'help'], [8, 'he']] [[11, 'parents']]
# Tom asked his teacher
# [] [] [] [[1, 'Tom asked his teacher']]
# New stripped sentence =  [[1, 'help']] [] [[1, 'VBab']] [[1, 'CCab']]
# Origial sentence connotation=  [[1, 'Tom'], [4, 'teacher'], [6, 'help'], [8, 'he']] [[11, 'parents']]
# [] [[2, 'help']] [] [[1, 'Tom asked his teacher']]
# New stripped sentence =  [[1, 'he']] [[4, 'parents']] [[2, 'asked']] [[5, 'CCab']]
# Origial sentence connotation=  [[1, 'Tom'], [4, 'teacher'], [6, 'help'], [8, 'he']] [[11, 'parents']]
# he asked his parents.
#
# [] [[2, 'help']] [] [[1, 'Tom asked his teacher'], [3, 'he asked his parents.\n']]
# Tom asked his teacher
# he asked his parents.
# help asked his parents.
# New stripped sentence =  [[1, 'Janet']] [[5, 'sushi']] [[2, 'does'], [4, 'like']] [[5, 'CCab']]
# Origial sentence connotation=  [[1, 'Janet'], [5, 'sushi']] [[8, 'she'], [11, 'kind']]
# Janet doesnt like sushi
# [] [] [] [[1, 'Janet doesnt like sushi']]
# New stripped sentence =  [] [[2, 'she'], [5, 'kind'], [7, 'fish']] [[1, 'does']] [[8, 'CCab']]
# Origial sentence connotation=  [[1, 'Janet'], [5, 'sushi']] [[8, 'she'], [11, 'kind']]
# [[2, 'does she like any kind of fish.\n']] [] [] [[1, 'Janet doesnt like sushi']]
# Janet doesnt like sushi
# Janet does she like any kind of fish.
# New stripped sentence =  [[1, 'Ms.'], [2, 'Tory']] [[7, 'hand']] [[3, 'held']] [[7, 'CCab']]
# Origial sentence connotation=  [[1, 'Ms.'], [2, 'Tory'], [7, 'hand'], [9, 'she']] []
# Ms. Tory held Margaretâ€™s hand
# [] [] [] [[1, 'Ms. Tory held Margaretâ€™s hand']]
# New stripped sentence =  [[1, 'she']] [] [[2, 'did'], [4, 'speak']] [[5, 'CCab']]
# Origial sentence connotation=  [[1, 'Ms.'], [2, 'Tory'], [7, 'hand'], [9, 'she']] []
# she did not speak.
#
# [] [] [] [[1, 'Ms. Tory held Margaretâ€™s hand'], [2, 'she did not speak.\n']]
# Ms. Tory held Margaretâ€™s hand
# she did not speak.
# New stripped sentence =  [[1, 'Maizon'], [3, 'Margaret']] [[6, 'things']] [[2, 'kept'], [5, 'doing']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'Maizon'], [3, 'Margaret'], [6, 'things'], [9, 'Maison']] []
# Maizon kept Margaret from doing things
# [] [] [] [[1, 'Maizon kept Margaret from doing things']]
# New stripped sentence =  [[2, 'Maison']] [] [[3, 'is'], [4, 'gone']] [[5, 'CCab']]
# Origial sentence connotation=  [[1, 'Maizon'], [3, 'Margaret'], [6, 'things'], [9, 'Maison']] []
# now Maison is gone.
#
# [] [] [] [[1, 'Maizon kept Margaret from doing things'], [2, 'now Maison is gone.\n']]
# Maizon kept Margaret from doing things
# now Maison is gone.
# New stripped sentence =  [[1, 'Margaret']] [[5, 'things']] [[2, 'will'], [3, 'try']] [[5, 'CCab']]
# Origial sentence connotation=  [[1, 'Margaret'], [5, 'things'], [7, 'she']] []
# Margaret will try new things
# [] [] [] [[1, 'Margaret will try new things']]
# New stripped sentence =  [[1, 'she']] [] [[2, 'will'], [3, 'stay']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'Margaret'], [5, 'things'], [7, 'she']] []
# she will stay the same.
#
# [] [] [] [[1, 'Margaret will try new things'], [2, 'she will stay the same.\n']]
# Margaret will try new things
# she will stay the same.
# New stripped sentence =  [[1, 'Margaretâ€'], [3, 's'], [4, 'dad']] [] [[5, 'died']] [[5, 'CCab']]
# Origial sentence connotation=  [[1, 'Margaretâ€'], [3, 's'], [4, 'dad'], [7, 'she']] [[9, 'her']]
# Margaretâ€™s dad died
# [] [] [] [[1, 'Margaretâ€™s dad died']]
# New stripped sentence =  [[1, 'she']] [[3, 'her'], [5, 'friend']] [[2, 'lost']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'Margaretâ€'], [3, 's'], [4, 'dad'], [7, 'she']] [[9, 'her']]
# she lost her best friend.
#
# [] [] [] [[1, 'Margaretâ€™s dad died'], [2, 'she lost her best friend.\n']]
# Margaretâ€™s dad died
# she lost her best friend.
# New stripped sentence =  [[2, 'summer']] [[5, 'sadness']] [[3, 'had'], [4, 'brought']] [[5, 'CCab']]
# Origial sentence connotation=  [[2, 'summer'], [5, 'sadness'], [7, 'Margaret']] []
# The summer had brought sadness
# [] [] [] [[1, 'The summer had brought sadness']]
# New stripped sentence =  [[1, 'Margaret']] [] [[2, 'had'], [3, 'suffered']] [[4, 'CCab']]
# Origial sentence connotation=  [[2, 'summer'], [5, 'sadness'], [7, 'Margaret']] []
# Margaret had suffered.
#
# [] [] [] [[1, 'The summer had brought sadness'], [2, 'Margaret had suffered.\n']]
# The summer had brought sadness
# Margaret had suffered.
# New stripped sentence =  [[2, 'summer']] [] [[3, 'might'], [4, 'be']] [[5, 'CCab']]
# Origial sentence connotation=  [[2, 'summer'], [7, 'it']] []
# Next summer might be better
# [] [] [] [[1, 'Next summer might be better']]
# New stripped sentence =  [[1, 'it']] [] [[2, 'might'], [3, 'be']] [[5, 'CCab']]
# Origial sentence connotation=  [[2, 'summer'], [7, 'it']] []
# it might be worse.
#
# [] [] [] [[1, 'Next summer might be better'], [2, 'it might be worse.\n']]
# Next summer might be better
# it might be worse.
# New stripped sentence =  [[1, 'Margaret']] [] [[2, 'hoped']] [[2, 'CCab']]
# Origial sentence connotation=  [[1, 'Margaret'], [5, 'times'], [7, 'she']] [[10, 't']]
# Margaret hoped
# [] [] [] [[1, 'Margaret hoped']]
# New stripped sentence =  [[2, 'times']] [] [[2, 'VBab']] [[2, 'CCab']]
# Origial sentence connotation=  [[1, 'Margaret'], [5, 'times'], [7, 'she']] [[10, 't']]
# [] [[2, 'better times']] [] [[1, 'Margaret hoped']]
# New stripped sentence =  [[1, 'she']] [[4, 't'], [5, 'count'], [7, 'them']] [[2, 'couldnâ€']] [[8, 'CCab']]
# Origial sentence connotation=  [[1, 'Margaret'], [5, 'times'], [7, 'she']] [[10, 't']]
# she couldnâ€™t count on them.
#
# [] [[2, 'better times']] [] [[1, 'Margaret hoped'], [3, 'she couldnâ€™t count on them.\n']]
# Margaret hoped
# she couldnâ€™t count on them.
# better times couldnâ€™t count on them.
# New stripped sentence =  [[1, 'Margaretâ€'], [4, 'poem']] [] [[5, 'is']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'Margaretâ€'], [4, 'poem'], [8, 'it']] []
# Margaretâ€™s poem is long
# [] [] [] [[1, 'Margaretâ€™s poem is long']]
# New stripped sentence =  [[1, 'it']] [] [[2, 'is'], [4, 'complicated']] [[5, 'CCab']]
# Origial sentence connotation=  [[1, 'Margaretâ€'], [4, 'poem'], [8, 'it']] []
# it is not complicated.
#
# [] [] [] [[1, 'Margaretâ€™s poem is long'], [2, 'it is not complicated.\n']]
# Margaretâ€™s poem is long
# it is not complicated.
# New stripped sentence =  [[1, 'Margart']] [[5, 'Maizon'], [8, 'poem']] [[2, 'does'], [4, 'discuss']] [[8, 'CCab']]
# Origial sentence connotation=  [[1, 'Margart'], [5, 'Maizon'], [8, 'poem'], [10, 'she']] [[15, 'fatherâ€']]
# Margart does not discuss Maizon in this poem
# [] [] [] [[1, 'Margart does not discuss Maizon in this poem']]
# New stripped sentence =  [[1, 'she']] [[6, 'fatherâ€'], [9, 'death']] [[2, 'does'], [3, 'tell']] [[10, 'CCab']]
# Origial sentence connotation=  [[1, 'Margart'], [5, 'Maizon'], [8, 'poem'], [10, 'she']] [[15, 'fatherâ€']]
# she does tell about her fatherâ€™s death.
#
# [] [] [] [[1, 'Margart does not discuss Maizon in this poem'], [2, 'she does tell about her fatherâ€™s death.\n']]
# Margart does not discuss Maizon in this poem
# she does tell about her fatherâ€™s death.
# New stripped sentence =  [[2, 'poem']] [[7, 'mother']] [[3, 'mentions']] [[7, 'CCab']]
# Origial sentence connotation=  [[2, 'poem'], [7, 'mother'], [9, 'it']] [[11, 'advice']]
# The poem mentions Margaretâ€™s mother
# [] [] [] [[1, 'The poem mentions Margaretâ€™s mother']]
# New stripped sentence =  [[1, 'it']] [[3, 'advice'], [5, 'Ms.'], [6, 'Dell']] [[2, 'quotes']] [[7, 'CCab']]
# Origial sentence connotation=  [[2, 'poem'], [7, 'mother'], [9, 'it']] [[11, 'advice']]
# it quotes advice from Ms. Dell.
#
# [] [] [] [[1, 'The poem mentions Margaretâ€™s mother'], [2, 'it quotes advice from Ms. Dell.\n']]
# The poem mentions Margaretâ€™s mother
# it quotes advice from Ms. Dell.
# New stripped sentence =  [[1, 'Margaret']] [[8, 'poem']] [[2, 'could'], [3, 'have'], [4, 'refused'], [6, 'write']] [[8, 'CCab']]
# Origial sentence connotation=  [[1, 'Margaret'], [8, 'poem'], [10, 'she']] [[16, 'it']]
# Margaret could have refused to write the poem
# [] [] [] [[1, 'Margaret could have refused to write the poem']]
# New stripped sentence =  [[1, 'she']] [[7, 'it'], [10, 'class']] [[2, 'could'], [3, 'have'], [4, 'refused'], [6, 'read']] [[11, 'CCab']]
# Origial sentence connotation=  [[1, 'Margaret'], [8, 'poem'], [10, 'she']] [[16, 'it']]
# she could have refused to read it to the class.
#
# [] [] [] [[1, 'Margaret could have refused to write the poem'], [2, 'she could have refused to read it to the class.\n']]
# Margaret could have refused to write the poem
# she could have refused to read it to the class.
# New stripped sentence =  [[2, 'poem']] [] [[3, 'was'], [5, 'written']] [[5, 'CCab']]
# Origial sentence connotation=  [[2, 'poem'], [7, 'Ms.']] [[8, 'Peazle']]
# The poem was well written
# [] [] [] [[1, 'The poem was well written']]
# New stripped sentence =  [[1, 'Ms.'], [2, 'Peazle']] [[9, 'efforts']] [[3, 'was']] [[10, 'CCab']]
# Origial sentence connotation=  [[2, 'poem'], [7, 'Ms.']] [[8, 'Peazle']]
# Ms. Peazle was proud of Margaretâ€™s efforts.
#
# [] [] [] [[1, 'The poem was well written'], [2, 'Ms. Peazle was proud of Margaretâ€™s efforts.\n']]
# The poem was well written
# Ms. Peazle was proud of Margaretâ€™s efforts.
# New stripped sentence =  [[2, 'class']] [[6, 'anything'], [9, 'poem']] [[3, 'did'], [5, 'say']] [[9, 'CCab']]
# Origial sentence connotation=  [[2, 'class'], [6, 'anything'], [9, 'poem'], [11, 'they']] [[15, 'it']]
# The class did not say anything about the poem
# [] [] [] [[1, 'The class did not say anything about the poem']]
# New stripped sentence =  [[1, 'they']] [[5, 'it']] [[2, 'did'], [3, 'react']] [[6, 'CCab']]
# Origial sentence connotation=  [[2, 'class'], [6, 'anything'], [9, 'poem'], [11, 'they']] [[15, 'it']]
# they did react to it.
#
# [] [] [] [[1, 'The class did not say anything about the poem'], [2, 'they did react to it.\n']]
# The class did not say anything about the poem
# they did react to it.
# New stripped sentence =  [[3, 'one'], [5, 'what']] [] [[4, 'knew'], [7, 'say']] [[7, 'CCab']]
# Origial sentence connotation=  [[3, 'one'], [5, 'what'], [11, 'students']] [[18, 'thing']]
# Maybe no one knew what to say
# [] [] [] [[1, 'Maybe no one knew what to say']]
# New stripped sentence =  [[3, 'students']] [[10, 'thing']] [[4, 'were'], [7, 'say']] [[11, 'CCab']]
# Origial sentence connotation=  [[3, 'one'], [5, 'what'], [11, 'students']] [[18, 'thing']]
# maybe the students were afraid to say the wrong thing.
#
# [] [] [] [[1, 'Maybe no one knew what to say'], [2, 'maybe the students were afraid to say the wrong thing.\n']]
# Maybe no one knew what to say
# maybe the students were afraid to say the wrong thing.
# New stripped sentence =  [[2, 'students']] [] [[3, 'were']] [[4, 'CCab']]
# Origial sentence connotation=  [[2, 'students'], [6, 'Ms.']] [[7, 'Peazle']]
# The students were silent
# [] [] [] [[1, 'The students were silent']]
# New stripped sentence =  [[1, 'Ms.'], [2, 'Peazle'], [4, 'what']] [] [[3, 'knew'], [6, 'write']] [[7, 'CCab']]
# Origial sentence connotation=  [[2, 'students'], [6, 'Ms.']] [[7, 'Peazle']]
# Ms. Peazle knew what to write.
#
# [] [] [] [[1, 'The students were silent'], [2, 'Ms. Peazle knew what to write.\n']]
# The students were silent
# Ms. Peazle knew what to write.
# New stripped sentence =  [[2, 'dog']] [[4, 'fruit'], [7, 'kind']] [[3, 'eats']] [[7, 'CCab']]
# Origial sentence connotation=  [[2, 'dog'], [4, 'fruit'], [7, 'kind'], [9, 'she']] [[13, 'meat'], [15, 'cheese']]
# My dog eats fruit of any kind
# [] [] [] [[1, 'My dog eats fruit of any kind']]
# New stripped sentence =  [[1, 'she']] [[5, 'meat']] [[2, 'will'], [4, 'eat']] [[5, 'CCab']]
# Origial sentence connotation=  [[2, 'dog'], [4, 'fruit'], [7, 'kind'], [9, 'she']] [[13, 'meat'], [15, 'cheese']]
# she will not eat meat
# [] [] [] [[1, 'My dog eats fruit of any kind'], [2, 'she will not eat meat']]
# New stripped sentence =  [[1, 'cheese']] [] [[2, 'VBab']] [[2, 'CCab']]
# Origial sentence connotation=  [[2, 'dog'], [4, 'fruit'], [7, 'kind'], [9, 'she']] [[13, 'meat'], [15, 'cheese']]
# Check cheese [[13, 'meat'], [15, 'cheese']]
# [] [] [[3, 'cheese.\n']] [[1, 'My dog eats fruit of any kind'], [2, 'she will not eat meat']]
# My dog eats fruit of any kind
# she will not eat meat
# she will not eat cheese.
# New stripped sentence =  [[3, 'rug'], [6, 'living'], [7, 'room']] [] [[8, 'is']] [[9, 'CCab']]
# Origial sentence connotation=  [[3, 'rug'], [6, 'living'], [7, 'room'], [11, 'it']] [[16, 'furniture']]
# The new rug in the living room is beautiful
# [] [] [] [[1, 'The new rug in the living room is beautiful']]
# New stripped sentence =  [[1, 'it']] [[6, 'furniture']] [[2, 'does'], [4, 'match']] [[7, 'CCab']]
# Origial sentence connotation=  [[3, 'rug'], [6, 'living'], [7, 'room'], [11, 'it']] [[16, 'furniture']]
# it does not match the furniture.
#
# [] [] [] [[1, 'The new rug in the living room is beautiful'], [2, 'it does not match the furniture.\n']]
# The new rug in the living room is beautiful
# it does not match the furniture.
# New stripped sentence =  [[1, 'Kelly']] [] [[2, 'applied']] [[2, 'CCab']]
# Origial sentence connotation=  [[1, 'Kelly']] [[5, 'job'], [7, 'accounting']]
# Kelly applied
# [] [] [] [[1, 'Kelly applied']]
# New stripped sentence =  [[2, 'job']] [[9, 'facility'], [11, 'town']] [[4, 'accounting']] [[12, 'CCab']]
# Origial sentence connotation=  [[1, 'Kelly']] [[5, 'job'], [7, 'accounting']]
# a job in accounting at the new medical facility in town.
#
# [] [] [] [[1, 'Kelly applied'], [2, 'a job in accounting at the new medical facility in town.\n']]
# Kelly applied
# a job in accounting at the new medical facility in town.
# New stripped sentence =  [[2, 'mother']] [] [[3, 'mopped']] [[3, 'CCab']]
# Origial sentence connotation=  [[2, 'mother']] [[7, 'hardwood'], [8, 'floors']]
# My mother mopped
# [] [] [] [[1, 'My mother mopped']]
# New stripped sentence =  [] [[3, 'hardwood'], [4, 'floors'], [7, 'house']] [[1, 'waxed']] [[8, 'CCab']]
# Origial sentence connotation=  [[2, 'mother']] [[7, 'hardwood'], [8, 'floors']]
# [[2, 'waxed the hardwood floors in our house.\n']] [] [] [[1, 'My mother mopped']]
# My mother mopped
# mother waxed the hardwood floors in our house.
# New stripped sentence =  [[1, 'I']] [[5, 'store'], [8, 'list']] [[2, 'went']] [[8, 'CCab']]
# Origial sentence connotation=  [[1, 'I'], [5, 'store'], [8, 'list'], [10, 'I']] [[13, 'junk']]
# I went to the store without a list
# [] [] [] [[1, 'I went to the store without a list']]
# New stripped sentence =  [[1, 'I']] [[4, 'junk'], [5, 'food']] [[2, 'bought']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'I'], [5, 'store'], [8, 'list'], [10, 'I']] [[13, 'junk']]
# I bought all junk food.
#
# [] [] [] [[1, 'I went to the store without a list'], [2, 'I bought all junk food.\n']]
# I went to the store without a list
# I bought all junk food.
# New stripped sentence =  [[1, 'Bosco']] [[4, 'tail']] [[2, 'chased']] [[4, 'CCab']]
# Origial sentence connotation=  [[1, 'Bosco'], [4, 'tail'], [6, 'he']] [[10, 'it']]
# Bosco chased his tail
# [] [] [] [[1, 'Bosco chased his tail']]
# New stripped sentence =  [[1, 'he']] [[5, 'it']] [[3, 'did'], [4, 'catch']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'Bosco'], [4, 'tail'], [6, 'he']] [[10, 'it']]
# he never did catch it.
#
# [] [] [] [[1, 'Bosco chased his tail'], [2, 'he never did catch it.\n']]
# Bosco chased his tail
# he never did catch it.
# New stripped sentence =  [[1, 'Minnie']] [[4, 'Europe']] [[2, 'traveled']] [[4, 'CCab']]
# Origial sentence connotation=  [[1, 'Minnie'], [4, 'Europe']] [[9, 'castles']]
# Minnie traveled through Europe
# [] [] [] [[1, 'Minnie traveled through Europe']]
# New stripped sentence =  [] [[4, 'castles']] [[1, 'explored']] [[5, 'CCab']]
# Origial sentence connotation=  [[1, 'Minnie'], [4, 'Europe']] [[9, 'castles']]
# [[2, 'explored many interesting castles.\n']] [] [] [[1, 'Minnie traveled through Europe']]
# Minnie traveled through Europe
# Minnie explored many interesting castles.
# New stripped sentence =  [[1, 'Leslie']] [] [[1, 'VBab']] [[1, 'CCab']]
# Origial sentence connotation=  [[1, 'Leslie'], [3, 'Mark']] [[8, 'talent']]
# [] [[1, 'Leslie']] [] []
# New stripped sentence =  [[1, 'Mark']] [[6, 'talent'], [7, 'show']] [[2, 'will'], [3, 'sing']] [[8, 'CCab']]
# Origial sentence connotation=  [[1, 'Leslie'], [3, 'Mark']] [[8, 'talent']]
# Mark will sing in the talent show.
#
# [] [[1, 'Leslie']] [] [[2, 'Mark will sing in the talent show.\n']]
# Mark will sing in the talent show.
# Leslie will sing in the talent show.
# New stripped sentence =  [[1, 'Leslie']] [] [[2, 'will'], [3, 'sing']] [[3, 'CCab']]
# Origial sentence connotation=  [[1, 'Leslie']] [[8, 'talent'], [9, 'show']]
# Leslie will sing
# [] [] [] [[1, 'Leslie will sing']]
# New stripped sentence =  [[1, 'dance'], [4, 'talent'], [5, 'show']] [] [[6, 'VBab']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'Leslie']] [[8, 'talent'], [9, 'show']]
# [] [[2, 'dance in the talent show.\n']] [] [[1, 'Leslie will sing']]
# <class 'TypeError'>
# New stripped sentence =  [[1, 'Father']] [[4, 'carpenter'], [6, 'trade']] [[2, 'was']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'Father'], [4, 'carpenter'], [6, 'trade'], [8, 'he']] [[10, 'us']]
# Father was a carpenter by trade
# [] [] [] [[1, 'Father was a carpenter by trade']]
# New stripped sentence =  [[1, 'he']] [[3, 'us'], [6, 'home']] [[2, 'built']] [[7, 'CCab']]
# Origial sentence connotation=  [[1, 'Father'], [4, 'carpenter'], [6, 'trade'], [8, 'he']] [[10, 'us']]
# he built us a sturdy home.
#
# [] [] [] [[1, 'Father was a carpenter by trade'], [2, 'he built us a sturdy home.\n']]
# Father was a carpenter by trade
# he built us a sturdy home.
# New stripped sentence =  [[1, 'I']] [[4, 'arms'], [7, 'chest']] [[2, 'crossed']] [[7, 'CCab']]
# Origial sentence connotation=  [[1, 'I'], [4, 'arms'], [7, 'chest']] []
# I crossed my arms over my chest
# [] [] [] [[1, 'I crossed my arms over my chest']]
# New stripped sentence =  [] [[2, 'SBab']] [[1, 'pouted']] [[2, 'CCab']]
# Origial sentence connotation=  [[1, 'I'], [4, 'arms'], [7, 'chest']] []
# [[2, 'pouted.\n']] [] [] [[1, 'I crossed my arms over my chest']]
# I crossed my arms over my chest
# I pouted.
# New stripped sentence =  [[1, 'I']] [[7, 'quilt'], [9, 'disaster']] [[2, 'had'], [4, 'saved']] [[9, 'CCab']]
# Origial sentence connotation=  [[1, 'I'], [7, 'quilt'], [9, 'disaster'], [12, 'she']] [[14, 'it']]
# I had just saved her precious quilt from disaster
# [] [] [] [[1, 'I had just saved her precious quilt from disaster']]
# New stripped sentence =  [[2, 'she']] [[4, 'it']] [[1, 'would'], [3, 'appreciate']] [[4, 'CCab']]
# Origial sentence connotation=  [[1, 'I'], [7, 'quilt'], [9, 'disaster'], [12, 'she']] [[14, 'it']]
# she would appreciate it
# [] [] [] [[1, 'I had just saved her precious quilt from disaster'], [2, 'she would appreciate it ']]
# I had just saved her precious quilt from disaster
# she would appreciate it
# New stripped sentence =  [[2, 'water'], [5, 'washbasin']] [] [[6, 'was']] [[7, 'CCab']]
# Origial sentence connotation=  [[2, 'water'], [5, 'washbasin'], [10, 'facecloth']] [[14, 'cheese']]
# The water in the washbasin was cloudy
# [] [] [] [[1, 'The water in the washbasin was cloudy']]
# New stripped sentence =  [[2, 'facecloth']] [[6, 'cheese']] [[3, 'smelled']] [[7, 'CCab']]
# Origial sentence connotation=  [[2, 'water'], [5, 'washbasin'], [10, 'facecloth']] [[14, 'cheese']]
# the facecloth smelled like old cheese.
#
# [] [] [] [[1, 'The water in the washbasin was cloudy'], [2, 'the facecloth smelled like old cheese.\n']]
# The water in the washbasin was cloudy
# the facecloth smelled like old cheese.
# New stripped sentence =  [[2, 'father']] [[5, 'home']] [[3, 'built']] [[5, 'CCab']]
# Origial sentence connotation=  [[2, 'father'], [5, 'home'], [7, 'business'], [10, 'War'], [12, 'Independence']] []
# My father built our home
# [] [] [] [[1, 'My father built our home']]
# New stripped sentence =  [[1, 'business'], [4, 'War']] [] [[4, 'VBab']] [[4, 'CCab']]
# Origial sentence connotation=  [[2, 'father'], [5, 'home'], [7, 'business'], [10, 'War'], [12, 'Independence']] []
# [] [[2, 'business after the War']] [] [[1, 'My father built our home']]
# New stripped sentence =  [[1, 'Independence']] [] [[2, 'ended']] [[5, 'CCab']]
# Origial sentence connotation=  [[2, 'father'], [5, 'home'], [7, 'business'], [10, 'War'], [12, 'Independence']] []
# Independence ended in 1783.
#
# [] [[2, 'business after the War']] [] [[1, 'My father built our home'], [3, 'Independence ended in 1783.\n']]
# My father built our home
# Independence ended in 1783.
# business after the War ended in 1783.
# New stripped sentence =  [[2, 'room'], [4, 'we'], [6, 'customers']] [[12, 'floor']] [[5, 'served'], [7, 'filled']] [[12, 'CCab']]
# Origial sentence connotation=  [[2, 'room'], [4, 'we'], [6, 'customers'], [12, 'floor']] [[17, 'windows']]
# The room where we served customers filled most of the first floor
# [] [] [] [[1, 'The room where we served customers filled most of the first floor']]
# New stripped sentence =  [] [[4, 'windows']] [[1, 'had']] [[5, 'CCab']]
# Origial sentence connotation=  [[2, 'room'], [4, 'we'], [6, 'customers'], [12, 'floor']] [[17, 'windows']]
# [[2, 'had four large windows.\n']] [] [] [[1, 'The room where we served customers filled most of the first floor']]
# The room where we served customers filled most of the first floor
# room had four large windows.
# New stripped sentence =  [[1, 'Joe']] [] [[2, 'camped']] [[2, 'CCab']]
# Origial sentence connotation=  [[1, 'Joe']] [[7, 'Boy'], [8, 'Scout']]
# Joe camped
# [] [] [] [[1, 'Joe camped']]
# New stripped sentence =  [] [[4, 'Boy'], [5, 'Scout'], [6, 'troop']] [[1, 'hiked']] [[7, 'CCab']]
# Origial sentence connotation=  [[1, 'Joe']] [[7, 'Boy'], [8, 'Scout']]
# [[2, 'hiked with his Boy Scout troop.\n']] [] [] [[1, 'Joe camped']]
# Joe camped
# Joe hiked with his Boy Scout troop.
# New stripped sentence =  [[1, 'She']] [[7, 'test']] [[2, 'did'], [4, 'cheat']] [[7, 'CCab']]
# Origial sentence connotation=  [[1, 'She'], [7, 'test'], [9, 'it']] [[13, 'thing']]
# She did not cheat on the test
# [] [] [] [[1, 'She did not cheat on the test']]
# New stripped sentence =  [[1, 'it'], [5, 'thing']] [] [[2, 'was'], [7, 'do']] [[8, 'CCab']]
# Origial sentence connotation=  [[1, 'She'], [7, 'test'], [9, 'it']] [[13, 'thing']]
# it was the wrong thing to do.
#
# [] [] [] [[1, 'She did not cheat on the test'], [2, 'it was the wrong thing to do.\n']]
# She did not cheat on the test
# it was the wrong thing to do.
# New stripped sentence =  [[1, 'I']] [[7, 'work']] [[3, 'need'], [5, 'go']] [[7, 'CCab']]
# Origial sentence connotation=  [[1, 'I'], [7, 'work'], [9, 'I']] []
# I really need to go to work
# [] [] [] [[1, 'I really need to go to work']]
# New stripped sentence =  [[1, 'I']] [] [[2, 'am'], [6, 'drive']] [[7, 'CCab']]
# Origial sentence connotation=  [[1, 'I'], [7, 'work'], [9, 'I']] []
# I am too sick to drive.
#
# [] [] [] [[1, 'I really need to go to work'], [2, 'I am too sick to drive.\n']]
# I really need to go to work
# I am too sick to drive.
# New stripped sentence =  [[1, 'He']] [[5, 'money']] [[2, 'ran']] [[5, 'CCab']]
# Origial sentence connotation=  [[1, 'He'], [5, 'money'], [7, 'he']] [[12, 'poker']]
# He ran out of money
# [] [] [] [[1, 'He ran out of money']]
# New stripped sentence =  [[1, 'he']] [[6, 'poker']] [[2, 'had'], [4, 'stop'], [5, 'playing']] [[7, 'CCab']]
# Origial sentence connotation=  [[1, 'He'], [5, 'money'], [7, 'he']] [[12, 'poker']]
# he had to stop playing poker.
#
# [] [] [] [[1, 'He ran out of money'], [2, 'he had to stop playing poker.\n']]
# He ran out of money
# he had to stop playing poker.
# New stripped sentence =  [[1, 'They']] [] [[2, 'got']] [[4, 'CCab']]
# Origial sentence connotation=  [[1, 'They'], [6, 'they']] [[10, 'seats']]
# They got there early
# [] [] [] [[1, 'They got there early']]
# New stripped sentence =  [[1, 'they']] [[5, 'seats']] [[2, 'got']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'They'], [6, 'they']] [[10, 'seats']]
# they got really good seats.
#
# [] [] [] [[1, 'They got there early'], [2, 'they got really good seats.\n']]
# They got there early
# they got really good seats.
# New stripped sentence =  [[1, 'They'], [4, 'ice'], [5, 'cream']] [[8, 'home']] [[2, 'had'], [6, 'left']] [[8, 'CCab']]
# Origial sentence connotation=  [[1, 'They'], [4, 'ice'], [5, 'cream'], [8, 'home'], [11, 'they']] [[13, 'money']]
# They had no ice cream left at home
# [] [] [] [[1, 'They had no ice cream left at home']]
# New stripped sentence =  [[2, 'they'], [4, 'money']] [[9, 'store']] [[1, 'did'], [3, 'have'], [6, 'go']] [[10, 'CCab']]
# Origial sentence connotation=  [[1, 'They'], [4, 'ice'], [5, 'cream'], [8, 'home'], [11, 'they']] [[13, 'money']]
# they did have money to go to the store.
# [] [] [] [[1, 'They had no ice cream left at home'], [2, 'they did have money to go to the store. ']]
# They had no ice cream left at home
# they did have money to go to the store.
# New stripped sentence =  [[1, 'Everyone']] [] [[2, 'was']] [[3, 'CCab']]
# Origial sentence connotation=  [[1, 'Everyone'], [5, 'I']] [[9, 'movie']]
# Everyone was busy
# [] [] [] [[1, 'Everyone was busy']]
# New stripped sentence =  [[1, 'I']] [[5, 'movie']] [[2, 'went']] [[7, 'CCab']]
# Origial sentence connotation=  [[1, 'Everyone'], [5, 'I']] [[9, 'movie']]
# I went to the movie alone.
#
# [] [] [] [[1, 'Everyone was busy'], [2, 'I went to the movie alone.\n']]
# Everyone was busy
# I went to the movie alone.
# New stripped sentence =  [[1, 'I'], [4, 'promotion']] [[6, 'mine']] [[2, 'thought'], [5, 'was']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'I'], [4, 'promotion'], [6, 'mine'], [9, 'attendance']] []
# I thought the promotion was mine
# [] [] [] [[1, 'I thought the promotion was mine']]
# New stripped sentence =  [[2, 'attendance']] [] [[3, 'was']] [[7, 'CCab']]
# Origial sentence connotation=  [[1, 'I'], [4, 'promotion'], [6, 'mine'], [9, 'attendance']] []
# my attendance wasnt good enough.
#
# [] [] [] [[1, 'I thought the promotion was mine'], [2, 'my attendance wasnt good enough.\n']]
# I thought the promotion was mine
# my attendance wasnt good enough.
# New stripped sentence =  [[2, 'we']] [[4, 'class']] [[1, 'Should'], [3, 'start']] [[5, 'CCab']]
# Origial sentence connotation=  [[2, 'we'], [4, 'class'], [9, 'everyone']] []
# we Should start class now
# [] [] [] [[1, 'we Should start class now ']]
# New stripped sentence =  [[1, 'SBab']] [] [[1, 'wait']] [[1, 'CCab']]
# Origial sentence connotation=  [[2, 'we'], [4, 'class'], [9, 'everyone']] []
# [] [] [] [[1, 'we Should start class now '], [2, 'wait']]
# New stripped sentence =  [[1, 'everyone']] [] [[3, 'get']] [[4, 'CCab']]
# Origial sentence connotation=  [[2, 'we'], [4, 'class'], [9, 'everyone']] []
# everyone to get here
#
# [] [] [] [[1, 'we Should start class now '], [2, 'wait'], [3, 'everyone to get here\n']]
# we Should start class now
# wait
# everyone to get here
# New stripped sentence =  [[1, 'It']] [] [[2, 'was'], [3, 'getting']] [[4, 'CCab']]
# Origial sentence connotation=  [[1, 'It'], [6, 'we']] [[11, 'cabin']]
# It was getting dark
# [] [] [] [[1, 'It was getting dark']]
# New stripped sentence =  [[1, 'we']] [[6, 'cabin']] [[2, 'were']] [[8, 'CCab']]
# Origial sentence connotation=  [[1, 'It'], [6, 'we']] [[11, 'cabin']]
# we werent near the cabin yet.
#
# [] [] [] [[1, 'It was getting dark'], [2, 'we werent near the cabin yet.\n']]
# It was getting dark
# we werent near the cabin yet.
# New stripped sentence =  [[1, 'Cats']] [[4, 'pets']] [[2, 'are']] [[4, 'CCab']]
# Origial sentence connotation=  [[1, 'Cats'], [4, 'pets'], [6, 'they']] []
# Cats are good pets
# [] [] [] [[1, 'Cats are good pets']]
# New stripped sentence =  [[1, 'they']] [] [[2, 'are']] [[3, 'CCab']]
# Origial sentence connotation=  [[1, 'Cats'], [4, 'pets'], [6, 'they']] []
# they are clean
# [] [] [] [[1, 'Cats are good pets'], [2, 'they are clean']]
# New stripped sentence =  [] [[4, 'SBab']] [[1, 'are']] [[4, 'CCab']]
# Origial sentence connotation=  [[1, 'Cats'], [4, 'pets'], [6, 'they']] []
# [[3, 'are not noisy.\n']] [] [] [[1, 'Cats are good pets'], [2, 'they are clean']]
# Cats are good pets
# they are clean
# they are not noisy.
# New stripped sentence =  [[1, 'We']] [[6, 'Asia']] [[2, 'have'], [4, 'been']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'We'], [6, 'Asia'], [9, 'we']] [[11, 'Africa']]
# We have never been to Asia
# [] [] [] [[1, 'We have never been to Asia']]
# New stripped sentence =  [[2, 'we']] [[4, 'Africa']] [[1, 'have'], [3, 'visited']] [[5, 'CCab']]
# Origial sentence connotation=  [[1, 'We'], [6, 'Asia'], [9, 'we']] [[11, 'Africa']]
# we have visited Africa.
# [] [] [] [[1, 'We have never been to Asia'], [2, 'we have visited Africa. ']]
# We have never been to Asia
# we have visited Africa.
# New stripped sentence =  [] [[6, 'reason']] [[4, 'was']] [[6, 'CCab']]
# Origial sentence connotation=  [[6, 'reason'], [10, 'time']] [[13, 'us']]
# Check reason [[6, 'reason'], [10, 'time']]
# at least that was her reason
# [] [] [] [[1, 'at least that was her reason']]
# New stripped sentence =  [[3, 'time']] [[6, 'us']] [[2, 'having'], [5, 'join']] [[7, 'CCab']]
# Origial sentence connotation=  [[6, 'reason'], [10, 'time']] [[13, 'us']]
# not having time to join us.
#
# [] [] [] [[1, 'at least that was her reason'], [2, 'not having time to join us.\n']]
# at least that was her reason
# not having time to join us.
# New stripped sentence =  [[1, 'You']] [[7, 'things']] [[2, 'need'], [4, 'pack']] [[7, 'CCab']]
# Origial sentence connotation=  [[1, 'You'], [7, 'things']] []
# You need to pack the appropriate things
# [] [] [] [[1, 'You need to pack the appropriate things']]
# New stripped sentence =  [[1, 'camping']] [] [[1, 'VBab']] [[1, 'CCab']]
# Origial sentence connotation=  [[1, 'You'], [7, 'things']] []
# [] [[2, 'camping\n']] [] [[1, 'You need to pack the appropriate things']]
# <class 'TypeError'>
# New stripped sentence =  [[1, 'example'], [4, 'bag']] [[7, 'you']] [[3, 'sleeping'], [5, 'will'], [6, 'keep']] [[9, 'CCab']]
# Origial sentence connotation=  [[2, 'example'], [5, 'bag']] [[8, 'you']]
# example a sleeping bag will keep you warm.
#
# [] [] [] [[1, 'example a sleeping bag will keep you warm.\n']]
# example a sleeping bag will keep you warm.
# New stripped sentence =  [[1, 'He']] [] [[2, 'must'], [3, 'run']] [[4, 'CCab']]
# Origial sentence connotation=  [[1, 'He'], [6, 'he']] [[11, 'train']]
# He must run fast
# [] [] [] [[1, 'He must run fast']]
# New stripped sentence =  [[1, 'he']] [[6, 'train']] [[2, 'will'], [4, 'catch']] [[7, 'CCab']]
# Origial sentence connotation=  [[1, 'He'], [6, 'he']] [[11, 'train']]
# he will not catch the train.
#
# [] [] [] [[1, 'He must run fast'], [2, 'he will not catch the train.\n']]
# He must run fast
# he will not catch the train.
# New stripped sentence =  [[2, 'sun']] [] [[3, 'rose']] [[3, 'CCab']]
# Origial sentence connotation=  [[2, 'sun'], [6, 'sky']] []
# The sun rose
# [] [] [] [[1, 'The sun rose']]
# New stripped sentence =  [[2, 'sky']] [] [[3, 'cleared']] [[4, 'CCab']]
# Origial sentence connotation=  [[2, 'sun'], [6, 'sky']] []
# the sky cleared.
#
# [] [] [] [[1, 'The sun rose'], [2, 'the sky cleared.\n']]
# The sun rose
# the sky cleared.
# New stripped sentence =  [[1, 'He']] [] [[3, 'failed']] [[3, 'CCab']]
# Origial sentence connotation=  [[1, 'He'], [5, 'he']] []
# He repeatedly failed
# [] [] [] [[1, 'He repeatedly failed']]
# New stripped sentence =  [[1, 'he']] [] [[2, 'did'], [4, 'give']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'He'], [5, 'he']] []
# he did not give up.
#
# [] [] [] [[1, 'He repeatedly failed'], [2, 'he did not give up.\n']]
# He repeatedly failed
# he did not give up.
# New stripped sentence =  [[1, 'They']] [[6, 'shop']] [[4, 'looted']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'They'], [6, 'shop']] [[10, 'it'], [12, 'fire']]
# They not only looted the shop
# [] [] [] [[1, 'They not only looted the shop']]
# New stripped sentence =  [] [[3, 'it'], [5, 'fire']] [[2, 'set']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'They'], [6, 'shop']] [[10, 'it'], [12, 'fire']]
# [[2, 'also set it on fire.\n']] [] [] [[1, 'They not only looted the shop']]
# They not only looted the shop
# They also set it on fire.
# New stripped sentence =  [[1, 'He']] [[5, 'me'], [8, 'employers']] [[4, 'recommended']] [[8, 'CCab']]
# Origial sentence connotation=  [[1, 'He'], [5, 'me'], [8, 'employers']] [[11, 'me'], [13, 'money']]
# He not only recommended me to several employers
# [] [] [] [[1, 'He not only recommended me to several employers']]
# New stripped sentence =  [] [[2, 'me'], [4, 'money']] [[1, 'lent']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'He'], [5, 'me'], [8, 'employers']] [[11, 'me'], [13, 'money']]
# Check me [[1, 'He'], [5, 'me'], [8, 'employers']]
# me lent some money also.
# [] [] [] [[1, 'He not only recommended me to several employers'], [2, 'me lent some money also. ']]
# He not only recommended me to several employers
# me lent some money also.

# %%
sen  = "I have never visited africa nor have I visited Asia"

# %%
subjlst,objlst,broke,check = rule_1(sen)

# %%
get_it_all_spacy(sen)
# Out:
# ([[1, 'I'], [5, 'africa'], [8, 'I']],
#  [[10, 'Asia']],
#  [[2, 'have'], [4, 'visited'], [7, 'have'], [9, 'visited']],
#  [[6, 'nor']])

# %%
allavail = list()
empsubjlst = list()
empobjlst = list()
empverblst = list()
onlyobjlst = list()
onlysubjlst = list()
count=0;
total = len(broke)
for i in broke:
    ## Checks all sentences of the conjunction broke sentences. 
    subj=1;
    verb=1;
    obj=1;
    count+=1
    ## The following line gets the broken sentence's predicate subject and object.
    subj2lst,obj2lst,verb2lst,cc2lst = get_it_all_spacy(i.strip())
    print("New stripped sentence = ",subj2lst,obj2lst,verb2lst,cc2lst)
    print("Origial sentence connotation= ",subjlst,objlst)
    ## if no subject: turn variable of subj 0 to denote.. no subject.
    if len(subj2lst)==0:
        subj=0
        if len(obj2lst)!=0:
            ## it is possible that object of the sentence may not be an object in the 
            ## original sentence before breaking by conjunction instead could be a subject
            ## in such case it finds the whether subject or object of original sentence
            ## and makes subj variable 1 and obj variable 0
            if any(obj2lst[0][1] in ls for ls in subjlst):
                print("Check",obj2lst[0][1],subjlst)
                subj=1
                obj=0
    if len(obj2lst)==0:
        obj=0;
        ## Similarly performs similar checking for subject of the sentence and makes 
        ## necessary variables show it. 
        if len(subj2lst)!=0:
            if any(subj2lst[0][1] in ls for ls in objlst):
                print("Check",subj2lst[0][1],objlst)
                subj=0
                obj=1
    ## If there is no verb in the sentence.. in case of dependent clauses. 
    if verb2lst[0][1]=="VBab":
        verb=0;
    if subj==0 and verb!=0 and obj!=0:
        ## empsubjlst is for the dependant clauses.. - rule 3
        empsubjlst.append([count,i])
    if subj==0 and verb==0 and obj!=0:
        ## onlyobjlst is for the independant clauses -- rule2
        onlyobjlst.append([count,i])
    if subj!=0 and verb!=0:
        ## allavail -- clauses that are simple and independent
        lstnew = list()
        if verb2lst[0][0]==1:
            lstnew = i.split()
            temp = lstnew[0]
            lstnew[0]=lstnew[1]
            lstnew[1] = temp
            i=""
            for word in lstnew:
                i+=word+ " "
        print(i)
        allavail.append([count,i])
    if subj!=0 and verb==0 and obj==0:
        ## For reverse rule 2 case where only subject exists in the dependant clause.
        onlysubjlst.append([count,i])
    print(empsubjlst,onlysubjlst,onlyobjlst,allavail)
# Check for case in Rule2 or Rule3:
if len(broke)==len(allavail):
#         fw.write("Sentence = "+sen+"\n")
    for i in allavail:
        print(re.sub(' +', ' ',i[1]).strip())
#             fw.write("\t"+re.sub(' +', ' ',i[1]).strip()+"\n") 
#         fw.write("\n-----\n")
else:
    try:
        allavail = rule_2_3(empsubjlst,allavail,onlyobjlst,onlysubjlst)
#             fw.write("Sentence = "+sen+"\n")
        for i in allavail:
            print(re.sub(r'\b(.+)\s+\1\b', r'\1', re.sub(' +', ' ',i[1]).strip()))
#                 fw.write("\t"+re.sub(r'\b(.+)\s+\1\b', r'\1', re.sub(' +', ' ',i[1]).strip())+"\n")
#             fw.write("\n-----\n")
    except:
#             fw.write("Sentence = "+sen+"\n")
        print(sys.exc_info()[0])
#             fw.write("\tAlready Simple\n")
#             fw.write("\n-----\n")
# Out:
# New stripped sentence =  [[1, 'I']] [[5, 'africa']] [[2, 'have'], [4, 'visited']] [[5, 'CCab']]
# Origial sentence connotation=  [[1, 'I'], [5, 'africa'], [8, 'I']] [[10, 'Asia']]
# I have never visited africa
# [] [] [] [[1, 'I have never visited africa']]
# New stripped sentence =  [[2, 'I']] [[4, 'Asia']] [[1, 'have'], [3, 'visited']] [[4, 'CCab']]
# Origial sentence connotation=  [[1, 'I'], [5, 'africa'], [8, 'I']] [[10, 'Asia']]
# I have visited Asia
# [] [] [] [[1, 'I have never visited africa'], [2, 'I have visited Asia ']]
# I have never visited africa
# I have visited Asia
