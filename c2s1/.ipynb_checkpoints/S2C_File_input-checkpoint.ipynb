# %%
import spacy
import sys
import nltk
import regex as re

# %% [markdown]
# ### Segregating the sentence into Subject predicate and object

# %%
def get_it_all_spacy(sen):
#     print(sen)
    doc = nlp(sen)
    count=0
    cclst = list()
    sublst = list()
    verblst = list()
    subjlst = list()
    objlst = list()
    for token in doc:
        count+=1
        ## Checks for the speech tag of word having a coordinating conjunction or "For" or "So"
        if "CC" in token.pos_ or " for " == " "+str(token)+" " or  " so " == " "+str(token)+" ":
            cclst.append([count,str(token)])
    if len(cclst)==0:
        ## Append the coordinating conjunction along with its relative position
        cclst.append([count,"CCab"])
    count = 0
    for token in doc:
        count+=1
        if "VERB" in token.pos_ or "AUX" in token.pos_:
            ## Checks for speech tag of word having verb
            verblst.append([count,str(token)])
    if len(verblst)==0:
        ## Append the verb along with its relative position
        verblst.append([count,"VBab"])
    count = 0
    for token in doc:
        count+=1
        if "NOUN" in token.pos_ or "PRON" in token.pos_ or "PROPN" in token.pos_:
            sublst.append([count,str(token)])
    if len(sublst)==0:
        ## Append the noun along with its relative position
        sublst.append([count,"SBab"])
#     print("Subject = ",sublst)
#     print("Verb = ",verblst)
    k=0
    r=0
    i=0;
    flag = 0
    ccoccur = cclst[i][0]
    verboccur = verblst[k][0]   
    try:
        ## Use the verb of the relative position with relative noun.
        ## If the verb occurs before the noun then append as object else append as subject.
        ## but this is not necessarily the case everytime.. 
        ## I like playing basketball and I like playing football. 
        ## In ^ above case -- "I" that occurs before the verb "like" is taken as subject. 
        ## but for the same case "basketball" since it occurs after "like" becomes object.
        ## this is the simple case.. in the same example.. if the verb is still "like" of the 
        ## first clause, then "I" of the second clause is made object, hence it is necessary to locate
        ## the correct verb with respect to which the noun is taken. 
        ## the following code deals with locating the verb
        while verboccur< sublst[r][0]: # Checks for auxillary verbal conditions
            k+=1
            verboccur = verblst[k][0]
    except: # If no auxillary verb
        k-=1
        verboccur = verblst[k][0]
    try:    
        flag = 0
        while (1):
            j = sublst[r]
#             print("Accessing , ",j[1],verblst[k][1])
            ccoccur = cclst[i][0]
            verboccur = verblst[k][0]
            if j[0]<=verboccur: # Checks whether subject occurs before or after the verb.. and accordingly appends.
                subjlst.append([j[0],j[1]])
            if j[0]>verboccur:
                objlst.append([j[0],j[1]])
            r+=1 # Iterating to next noun, 
            try:
                j = sublst[r] # If next noun exists
            except:
                j = sublst[r-1] # If next noun doesnt exist
            if j[0]>=verboccur: # Locate the next verb if the next noun exists
                try:
                    while(j[0]>verboccur):
                        k+=1
                        verboccur = verblst[k][0]
                except: # reflect back to previous verb if the next verb was not successfully located
                    k-=1
                    verboccur = verblst[k][0]
#                 print(k,verblst[k])
            if(flag==1): # Terminating condition check
                try:
                    objlst.append([sublst[r][0],sublst[r][1]]) # If noun exists then last noun is object
                except:
#                     print("no last object")
                    pass
#                 print("broke")
                break;

            if(sublst[r][0]>=ccoccur): # Creating terminating condition... 
                try:
                    i+=1    
                    ccoccur = cclst[i][0] # If no forward coordinating conjunction, then no more breaks required.
                except:
                    i-=1
                    flag = 1; # Hence check one last time for clause and then break
#             print(ccoccur)

    except:
#         print(sys.exc_info()[0])
        pass
#     print(subjlst,objlst)
#     print(verblst)
#     print(cclst)
    return (subjlst,objlst,verblst,cclst)
#Data preparation completed

# %% [markdown]
# ### Rule 1 segregation
# ##### -- Breaking conjunction

# %%
# Rule 1 segregation
# Breaking conjunction
def rule_1(sen):
    subjlst,objlst,verblst,cclst = get_it_all_spacy(sen)
    doc = nlp(sen)
#     print(subjlst,objlst,verblst,cclst)
    broke = list()
    i =0
    j=0
    count = len(cclst)
    if cclst[0][1] == "CCab" : # If no coordinating conjunction--already simple sentence
        return([],[],["Already Simple --- ",sen],1) # 1 == sends check to main to say "not a compound sentence"
    else:
        try:
            cap = cclst[i][1] # Locate the next coordinating conjunction and break the sentence further
            while (1):
#                 print(str(doc[j]))
    #             print(cap)
                cap = cclst[i][1]
                if str(cap).strip()==str(doc[j]):
    #                 print(str(doc[j]))
                    broke.append(j) # Append the location of the clauses to the broke list.
                    count-=1
                    if count!=0: # Check for multiple conjunctions
                        i+=1
                    else:
                        break
                j+=1
        except:
#             print(sys.exc_info()[0])
            pass
        # The following code appends the clause to the fin list depending on the broke locations.
        broke.append(len(str(doc))) 
#         print(broke)
        fin = list()
        fin.append(str(doc[0:broke[0]]))
        try:
            for i in range(len(broke)):
                fin.append(str(doc[broke[i]+1:broke[i+1]]))
        except:
#             print(sys.exec_info()[0])
            pass
    final= list()
    for i in fin:
    #     print(i)
        stri = str()    
        for j in i:
            stri+= j
        final.append(stri) # converting each word of the token to a string and appending the string
    broke = final
#     print(broke)
    for i in broke:
        if i == "": # if broke has any non existent string then remove.
            broke.remove(i)
    return (subjlst,objlst,broke,0) # Returns check as 0 to say "Compound sentence"

# %% [markdown]
# ### Rule 2 or Rule 3 check
# #### -- accordingly decompose

# %%
def rule_2_3(empsubjlst,allavail,onlyobjlst,onlysubjlst):
    count = 0
    try:
        # The following works on rule 2 or 3 check plus performs 
        # the rules on the lists provided it passes rule 1
        while len(empsubjlst)!=0: # If no subject then perform reverse rule 2
            # The following performs rule3
            extract = len(allavail)-1 # Gets the most recently used string to append to the subject. 
            subj3lst,obj3lst,verb3lst,cc3lst = get_it_all_spacy(allavail[extract][1])
            for i in empsubjlst:
                finstr= subj3lst[0][1]+" "+i[1] # appends the string to the subject
                count=subj3lst[0][0]+1
                allavail.append([count,finstr]) # appends the string to the list of simple sentences
#                 print(finstr)
                empsubjlst.remove(i) # removes the string from the incomplete sentence list
        while len(onlyobjlst)!=0: 
            # For normal rule2 usecase
            # extract finds the most recently used string
            # appends to that string the object
            # removes the incomplete clause and adds the complete simple sentence to the 
            # list of simple sentences.
            extract = len(allavail)-1
#             print(extract,len(allavail))
            subj3lst,obj3lst,verb3lst,cc3lst = get_it_all_spacy(allavail[extract][1])
            objlen=len(obj3lst)-1
            prestr = allavail[extract][1].replace(obj3lst[objlen][1],"")
        #     print(prestr)
            for i in onlyobjlst:
                finstr = prestr+" "+i[1]
                count=allavail[extract][0]+1
                allavail.append([count,finstr])
#                 print(finstr)
                onlyobjlst.remove(i)
        while len(onlysubjlst)!=0:
            # When only subject exists:
            # This is the reverse rule2 case:
            # gets the next complete sentence between which the subject exists.
            # appends this subject to the predicate and object of the corresponding found sentence
            # appends the final simple complete sentence to list of complete sentences
            # removes the incomplete sentence/ subject from the onlysubjlist.
            for i in onlysubjlst:
                extract = i[0]+1
                for j in range(len(allavail)):
                    if allavail[j][0] == extract:
                        extract = j
                        break
#                 print(extract)
                subj3lst,obj3lst,verb3lst,cc3lst = get_it_all_spacy(allavail[extract][1])
                subjlen = len(subj3lst)-1
                prestr = allavail[extract][1].replace(subj3lst[subjlen][1],"")
                finstr = i[1]+" "+prestr
                count=allavail[extract][0]+1
                allavail.append([count,finstr])
#                 print(finstr)
                onlysubjlst.remove(i)
        return (allavail)
    except:
#         print(sys.exc_info())
        pass

# %% [markdown]
# ### Main function.. performs rule 1 and checks whether rule1 is sufficient else performs rule2 or 3 check

# %%
# Rule 1 check
def main(sen,fw):
    subjlst,objlst,broke,check = rule_1(sen)
#     print("\n------\n")
    ## Check denotes whether the sentence is already simple or not.
    if(check):
        fw.write("Sentence = "+sen+"\n")
        for i in broke:
            fw.write("\t"+i+"\n")
        fw.write("\n----\n")
        return
    ## The following lists are used to segregate rule 1 complete/incomplete..
    ## if incomplete then prepares data for rule2 and 3
    allavail = list()
    empsubjlst = list()
    empobjlst = list()
    empverblst = list()
    onlyobjlst = list()
    onlysubjlst = list()
    count=0;
    total = len(broke)
    for i in broke:
        ## Checks all sentences of the conjunction broke sentences. 
        subj=1;
        verb=1;
        obj=1;
        count+=1
        ## The following line gets the broken sentence's predicate subject and object.
        subj2lst,obj2lst,verb2lst,cc2lst = get_it_all_spacy(i.strip())
        print("New stripped sentence = ",subj2lst,obj2lst,verb2lst,cc2lst)
        print("Origial sentence connotation= ",subjlst,objlst)
        ## if no subject: turn variable of subj 0 to denote.. no subject.
        if len(subj2lst)==0:
            subj=0
            if len(obj2lst)!=0:
                ## it is possible that object of the sentence may not be an object in the 
                ## original sentence before breaking by conjunction instead could be a subject
                ## in such case it finds the whether subject or object of original sentence
                ## and makes subj variable 1 and obj variable 0
                if any(obj2lst[0][1] in ls for ls in subjlst):
                    print("Check",obj2lst[0][1],subjlst)
                    subj=1
                    obj=0
        if len(obj2lst)==0:
            obj=0;
            ## Similarly performs similar checking for subject of the sentence and makes 
            ## necessary variables show it. 
            if len(subj2lst)!=0:
                if any(subj2lst[0][1] in ls for ls in objlst):
                    print("Check",subj2lst[0][1],objlst)
                    subj=0
                    obj=1
        ## If there is no verb in the sentence.. in case of dependent clauses. 
        if verb2lst[0][1]=="VBab":
            verb=0;
        if subj==0 and verb!=0 and obj!=0:
            ## empsubjlst is for the dependant clauses.. - rule 3
            empsubjlst.append([count,i])
        if subj==0 and verb==0 and obj!=0:
            ## onlyobjlst is for the independant clauses -- rule2
            onlyobjlst.append([count,i])
        if subj!=0 and verb!=0:
            ## allavail -- clauses that are simple and independent
            lstnew = list()
            it = i
            try:
                if verb2lst[0][0]==1:
                    lstnew = i.split()
                    temp = lstnew[0]
                    lstnew[0]=lstnew[1]
                    lstnew[1] = temp
                    i=""
                    for word in lstnew:
                        i+=word+ " "
                print(i)
            except:
                i = it;
            allavail.append([count,i])
        if subj!=0 and verb==0 and obj==0:
            ## For reverse rule 2 case where only subject exists in the dependant clause.
            onlysubjlst.append([count,i])
        print(empsubjlst,onlysubjlst,onlyobjlst,allavail)
    # Check for case in Rule2 or Rule3:
    if len(broke)==len(allavail):
        fw.write("Sentence = "+sen+"\n")
        for i in allavail:
            print(re.sub(' +', ' ',i[1]).strip())
            fw.write("\t"+re.sub(' +', ' ',i[1]).strip()+"\n") 
        fw.write("\n-----\n")
    else:
        try:
            allavail = rule_2_3(empsubjlst,allavail,onlyobjlst,onlysubjlst)
            fw.write("Sentence = "+sen+"\n")
            for i in allavail:
                print(re.sub(r'\b(.+)\s+\1\b', r'\1', re.sub(' +', ' ',i[1]).strip()))
                fw.write("\t"+re.sub(r'\b(.+)\s+\1\b', r'\1', re.sub(' +', ' ',i[1]).strip())+"\n")
            fw.write("\n-----\n")
        except:
            fw.write("Sentence = "+sen+"\n")
            print(sys.exc_info()[0])
            fw.write("\tAlready Simple\n")
            fw.write("\n-----\n")

# %% [markdown]
# #### Sepereate the sentences that have bare semi colon

# %%
def sep_semi(input):
    rw = open(input)
    fw = open("tempoutput.txt","w")
    for line in rw:
        line = re.sub("[^\P{P}\.;]|","",str(nlp(line)))
        fw.write(line+"\n")
#         r = line.split(". ")
#         for i in r:
#             if i==" ":
#                 r.remove(i)
# #         fw.write(line+"\n")
#         if(len(r)!=0):
#             for i in r:
#                 fw.write(i+"\n")
    rw.close()
    fw.close()
    rw = open("tempoutput.txt")
    lst = list()
    for line in rw:
        lst.append(line.split(";"))
    rw.close()
    rw = open("tempoutput.txt","w")
    for i in lst:
        if(len(i)>1):
            for sep in i:
                rw.write(sep.strip())
                rw.write("\n")
        else:
            rw.write(i[0])
#                 print(sep.strip())
    fw.close()
    rw.close()

# %% [markdown]
# ### Function that coordinates with the main

# %%
nlp = spacy.load("en_core_web_sm")
# Splits sentences by the semi colon
# also removes punctuations
sep_semi(input("Enter the location of the input file: "))
rw = open("tempoutput.txt")
fw = open("output.txt","w")
for i in rw:
    main(i,fw)   
rw.close()
fw.close()
# Out:
# Enter the location of the input file: datasetNYT.txt
# New stripped sentence =  [[3, 'bullet'], [4, 'shells']] [[8, 'blood'], [9, 'dries']] [[5, 'get'], [6, 'counted']] [[9, 'CCab']]
# Origial sentence connotation=  [[3, 'bullet'], [4, 'shells'], [8, 'blood'], [9, 'dries'], [13, 'candles'], [16, 'people'], [21, 'windows'], [24, 'crime']] [[25, 'scenes']]
# After the bullet shells get counted the blood dries
# [] [] [] [[1, 'After the bullet shells get counted the blood dries']]
# New stripped sentence =  [[3, 'candles'], [6, 'people']] [[11, 'windows']] [[4, 'burn'], [7, 'peer']] [[11, 'CCab']]
# Origial sentence connotation=  [[3, 'bullet'], [4, 'shells'], [8, 'blood'], [9, 'dries'], [13, 'candles'], [16, 'people'], [21, 'windows'], [24, 'crime']] [[25, 'scenes']]
# the votive candles burn out people peer down from   windows
# [] [] [] [[1, 'After the bullet shells get counted the blood dries'], [2, 'the votive candles burn out people peer down from   windows']]
# New stripped sentence =  [[2, 'crime'], [3, 'scenes'], [7, 'band'], [10, 'police'], [11, 'tape']] [[15, 'breeze']] [[1, 'see'], [4, 'gone'], [12, 'blowing']] [[15, 'CCab']]
# Origial sentence connotation=  [[3, 'bullet'], [4, 'shells'], [8, 'blood'], [9, 'dries'], [13, 'candles'], [16, 'people'], [21, 'windows'], [24, 'crime']] [[25, 'scenes']]
# crime see scenes gone cold a band of yellow police tape blowing in the breeze
# [] [] [] [[1, 'After the bullet shells get counted the blood dries'], [2, 'the votive candles burn out people peer down from   windows'], [3, 'crime see scenes gone cold a band of yellow police tape blowing in the breeze ']]
# After the bullet shells get counted the blood dries
# the votive candles burn out people peer down from windows
# crime see scenes gone cold a band of yellow police tape blowing in the breeze
# New stripped sentence =  [[2, 'South'], [3, 'Bronx'], [7, 'Harlem'], [8, 'River'], [10, 'Manhattan']] [] [[10, 'VBab']] [[10, 'CCab']]
# Origial sentence connotation=  [[2, 'South'], [3, 'Bronx'], [7, 'Harlem'], [8, 'River'], [10, 'Manhattan'], [13, 'shorthand'], [16, 'dysfunction']] [[19, 'violence']]
# [] [[1, 'The South Bronx just across the Harlem River from Manhattan']] [] []
# New stripped sentence =  [[2, 'shorthand']] [] [[2, 'VBab']] [[2, 'CCab']]
# Origial sentence connotation=  [[2, 'South'], [3, 'Bronx'], [7, 'Harlem'], [8, 'River'], [10, 'Manhattan'], [13, 'shorthand'], [16, 'dysfunction']] [[19, 'violence']]
# [] [[1, 'The South Bronx just across the Harlem River from Manhattan'], [2, 'once shorthand']] [] []
# New stripped sentence =  [[2, 'dysfunction'], [5, 'violence'], [7, 'levels']] [[14, 'parts'], [16, 'New'], [17, 'York'], [18, 'City']] [[4, 'suffers'], [10, 'slashed']] [[18, 'CCab']]
# Origial sentence connotation=  [[2, 'South'], [3, 'Bronx'], [7, 'Harlem'], [8, 'River'], [10, 'Manhattan'], [13, 'shorthand'], [16, 'dysfunction']] [[19, 'violence']]
# urban dysfunction still suffers violence at levels long ago slashed in many other parts of New York City
#
# [] [[1, 'The South Bronx just across the Harlem River from Manhattan'], [2, 'once shorthand']] [] [[3, 'urban dysfunction still suffers violence at levels long ago slashed in many other parts of New York City\n']]
# <class 'TypeError'>
# New stripped sentence =  [[3, 'citys'], [4, 'efforts'], [7, 'it']] [] [[6, 'fight'], [8, 'remain']] [[10, 'CCab']]
# Origial sentence connotation=  [[4, 'citys'], [5, 'efforts'], [8, 'it']] [[15, 'scandal']]
# yet the citys efforts to fight it remain splintered underfunded
# [] [] [] [[1, 'yet the citys efforts to fight it remain splintered underfunded']]
# New stripped sentence =  [] [[3, 'scandal']] [[1, 'burdened']] [[3, 'CCab']]
# Origial sentence connotation=  [[4, 'citys'], [5, 'efforts'], [8, 'it']] [[15, 'scandal']]
# [[2, 'burdened by scandal\n']] [] [] [[1, 'yet the citys efforts to fight it remain splintered underfunded']]
# yet the citys efforts to fight it remain splintered underfunded
# citys burdened by scandal
# New stripped sentence =  [[4, 'Precinct'], [8, 'tip'], [11, 'Bronx'], [16, 'minority'], [17, 'neighborhoods'], [20, 'country'], [21, 'people']] [] [[23, 'hounded']] [[23, 'CCab']]
# Origial sentence connotation=  [[4, 'Precinct'], [8, 'tip'], [11, 'Bronx'], [16, 'minority'], [17, 'neighborhoods'], [20, 'country'], [21, 'people'], [26, 'infractions']] [[32, 'protection'], [35, 'injury'], [37, 'death']]
# In the 40th Precinct at the southern tip of the Bronx as in other poor minority neighborhoods across the country people long hounded
# [] [] [] [[1, 'In the 40th Precinct at the southern tip of the Bronx as in other poor minority neighborhoods across the country people long hounded']]
# New stripped sentence =  [[1, 'infractions']] [] [[2, 'are'], [3, 'crying']] [[4, 'CCab']]
# Origial sentence connotation=  [[4, 'Precinct'], [8, 'tip'], [11, 'Bronx'], [16, 'minority'], [17, 'neighborhoods'], [20, 'country'], [21, 'people'], [26, 'infractions']] [[32, 'protection'], [35, 'injury'], [37, 'death']]
#   infractions are crying out
# [] [] [] [[1, 'In the 40th Precinct at the southern tip of the Bronx as in other poor minority neighborhoods across the country people long hounded'], [2, '  infractions are crying out']]
# New stripped sentence =  [[2, 'protection'], [5, 'injury']] [] [[5, 'VBab']] [[5, 'CCab']]
# Origial sentence connotation=  [[4, 'Precinct'], [8, 'tip'], [11, 'Bronx'], [16, 'minority'], [17, 'neighborhoods'], [20, 'country'], [21, 'people'], [26, 'infractions']] [[32, 'protection'], [35, 'injury'], [37, 'death']]
# Check protection [[32, 'protection'], [35, 'injury'], [37, 'death']]
# [] [] [[3, 'more protection against grievous injury']] [[1, 'In the 40th Precinct at the southern tip of the Bronx as in other poor minority neighborhoods across the country people long hounded'], [2, '  infractions are crying out']]
# New stripped sentence =  [[1, 'death']] [] [[1, 'VBab']] [[1, 'CCab']]
# Origial sentence connotation=  [[4, 'Precinct'], [8, 'tip'], [11, 'Bronx'], [16, 'minority'], [17, 'neighborhoods'], [20, 'country'], [21, 'people'], [26, 'infractions']] [[32, 'protection'], [35, 'injury'], [37, 'death']]
# Check death [[32, 'protection'], [35, 'injury'], [37, 'death']]
# [] [] [[3, 'more protection against grievous injury'], [4, 'death\n']] [[1, 'In the 40th Precinct at the southern tip of the Bronx as in other poor minority neighborhoods across the country people long hounded'], [2, '  infractions are crying out']]
# <class 'TypeError'>
# New stripped sentence =  [[4, 'citys'], [6, 'precincts'], [8, '40th']] [[12, 'murder'], [13, 'rate']] [[9, 'has']] [[13, 'CCab']]
# Origial sentence connotation=  [[4, 'citys'], [6, 'precincts'], [8, '40th'], [12, 'murder'], [13, 'rate'], [17, 'detectives']] [[20, 'crime']]
# Out of the citys 77 precincts the 40th has the highest murder rate
# [] [] [] [[1, 'Out of the citys 77 precincts the 40th has the highest murder rate']]
# New stripped sentence =  [[3, 'detectives'], [6, 'crime'], [8, 'disparities'], [10, 'staffing'], [16, 'neighborhoods'], [18, 'Manhattan']] [[22, 'New'], [23, 'York'], [24, 'Times'], [25, 'analysis'], [27, 'Police'], [28, 'Department'], [29, 'data']] [[7, 'reflecting'], [12, 'hit'], [19, 'according']] [[29, 'CCab']]
# Origial sentence connotation=  [[4, 'citys'], [6, 'precincts'], [8, '40th'], [12, 'murder'], [13, 'rate'], [17, 'detectives']] [[20, 'crime']]
# the fewest detectives per violent crime reflecting disparities in staffing that hit hardest in some neighborhoods outside Manhattan according to a New York Times analysis of Police Department data
#
# [] [] [] [[1, 'Out of the citys 77 precincts the 40th has the highest murder rate'], [2, 'the fewest detectives per violent crime reflecting disparities in staffing that hit hardest in some neighborhoods outside Manhattan according to a New York Times analysis of Police Department data\n']]
# Out of the citys 77 precincts the 40th has the highest murder rate
# the fewest detectives per violent crime reflecting disparities in staffing that hit hardest in some neighborhoods outside Manhattan according to a New York Times analysis of Police Department data
# New stripped sentence =  [[1, 'Investigators'], [4, 'precinct'], [10, 'number'], [12, 'cases'], [14, 'department'], [19, 'bosses'], [23, 'Police'], [24, 'Headquarters']] [] [[5, 'are'], [6, 'saddled'], [15, 'recommends'], [20, 'are'], [21, 'called'], [26, 'answer']] [[26, 'CCab']]
# Origial sentence connotation=  [[1, 'Investigators'], [4, 'precinct'], [10, 'number'], [12, 'cases'], [14, 'department'], [19, 'bosses'], [23, 'Police'], [24, 'Headquarters']] [[30, 'crime'], [31, 'rise']]
# Investigators in the precinct are saddled with twice the number of cases the department recommends even as their bosses are called to Police Headquarters to answer
# [] [] [] [[1, 'Investigators in the precinct are saddled with twice the number of cases the department recommends even as their bosses are called to Police Headquarters to answer']]
# New stripped sentence =  [[3, 'crime'], [4, 'rise'], [7, 'city'], [9, 'year']] [] [[9, 'VBab']] [[9, 'CCab']]
# Origial sentence connotation=  [[1, 'Investigators'], [4, 'precinct'], [10, 'number'], [12, 'cases'], [14, 'department'], [19, 'bosses'], [23, 'Police'], [24, 'Headquarters']] [[30, 'crime'], [31, 'rise']]
# Check crime [[30, 'crime'], [31, 'rise']]
# [] [] [[2, 'the sharpest crime rise in the city this year\n']] [[1, 'Investigators in the precinct are saddled with twice the number of cases the department recommends even as their bosses are called to Police Headquarters to answer']]
# <class 'TypeError'>
# New stripped sentence =  [[3, 'Bronx'], [5, 'resources']] [] [[6, 'are'], [7, 'squeezed']] [[7, 'CCab']]
# Origial sentence connotation=  [[4, 'Bronx'], [6, 'resources']] []
# across the Bronx investigative resources are squeezed
#
# [] [] [] [[1, 'across the Bronx investigative resources are squeezed\n']]
# across the Bronx investigative resources are squeezed
# New stripped sentence =  [[1, 'It']] [[6, 'rate'], [9, 'citys'], [11, 'boroughs']] [[2, 'has']] [[11, 'CCab']]
# Origial sentence connotation=  [[1, 'It']] [[6, 'rate'], [9, 'citys'], [11, 'boroughs'], [15, 'detective'], [16, 'staffing']]
# It has the highest   rate of the citys five boroughs
# [] [] [] [[1, 'It has the highest   rate of the citys five boroughs']]
# New stripped sentence =  [[3, 'detective'], [4, 'staffing']] [] [[4, 'VBab']] [[4, 'CCab']]
# Origial sentence connotation=  [[1, 'It']] [[6, 'rate'], [9, 'citys'], [11, 'boroughs'], [15, 'detective'], [16, 'staffing']]
# Check detective [[6, 'rate'], [9, 'citys'], [11, 'boroughs'], [15, 'detective'], [16, 'staffing']]
# [] [] [[2, 'the thinnest detective staffing\n']] [[1, 'It has the highest   rate of the citys five boroughs']]
# It has the highest rate of the citys five boroughs
# It has the highest rate of the citys five the thinnest detective staffing
# New stripped sentence =  [[7, 'detective'], [8, 'squads']] [] [[8, 'VBab']] [[8, 'CCab']]
# Origial sentence connotation=  [[7, 'detective'], [8, 'squads'], [11, 'crime']] [[14, 'city']]
# [] [[1, 'Nine of the 14   precinct detective squads']] [] []
# New stripped sentence =  [[2, 'crime'], [5, 'city']] [] [[6, 'are']] [[7, 'CCab']]
# Origial sentence connotation=  [[7, 'detective'], [8, 'squads'], [11, 'crime']] [[14, 'city']]
# violent crime in the city are there
#
# [] [[1, 'Nine of the 14   precinct detective squads']] [] [[2, 'violent crime in the city are there\n']]
# violent crime in the city are there
# Nine of the 14 precinct detective squads violent crime in the are there
# New stripped sentence =  [[2, 'homicide'], [3, 'squad']] [[6, 'detective']] [[4, 'has']] [[6, 'CCab']]
# Origial sentence connotation=  [[2, 'homicide'], [3, 'squad'], [6, 'detective'], [10, 'murders']] [[14, 'detective'], [19, 'murders'], [21, 'Upper'], [22, 'Manhattan'], [27, 'detective'], [29, 'murder']]
# its homicide squad has one detective
# [] [] [] [[1, 'its homicide squad has one detective']]
# New stripped sentence =  [[3, 'murders']] [[7, 'detective']] [[4, 'compared']] [[7, 'CCab']]
# Origial sentence connotation=  [[2, 'homicide'], [3, 'squad'], [6, 'detective'], [10, 'murders']] [[14, 'detective'], [19, 'murders'], [21, 'Upper'], [22, 'Manhattan'], [27, 'detective'], [29, 'murder']]
# every four murders compared with one detective
# [] [] [] [[1, 'its homicide squad has one detective'], [2, 'every four murders compared with one detective']]
# New stripped sentence =  [[4, 'murders'], [6, 'Upper'], [7, 'Manhattan']] [] [[7, 'VBab']] [[7, 'CCab']]
# Origial sentence connotation=  [[2, 'homicide'], [3, 'squad'], [6, 'detective'], [10, 'murders']] [[14, 'detective'], [19, 'murders'], [21, 'Upper'], [22, 'Manhattan'], [27, 'detective'], [29, 'murder']]
# Check murders [[14, 'detective'], [19, 'murders'], [21, 'Upper'], [22, 'Manhattan'], [27, 'detective'], [29, 'murder']]
# [] [] [[3, 'roughly every two murders in Upper Manhattan']] [[1, 'its homicide squad has one detective'], [2, 'every four murders compared with one detective']]
# New stripped sentence =  [[4, 'detective'], [6, 'murder'], [8, 'Lower'], [9, 'Manhattan']] [] [[9, 'VBab']] [[9, 'CCab']]
# Origial sentence connotation=  [[2, 'homicide'], [3, 'squad'], [6, 'detective'], [10, 'murders']] [[14, 'detective'], [19, 'murders'], [21, 'Upper'], [22, 'Manhattan'], [27, 'detective'], [29, 'murder']]
# Check detective [[14, 'detective'], [19, 'murders'], [21, 'Upper'], [22, 'Manhattan'], [27, 'detective'], [29, 'murder']]
# [] [] [[3, 'roughly every two murders in Upper Manhattan'], [4, 'more than one detective per murder in Lower Manhattan\n']] [[1, 'its homicide squad has one detective'], [2, 'every four murders compared with one detective']]
# its homicide squad has one detective
# every four murders compared with one detective
# every four murders compared with one roughly every two murders in Upper Manhattan
# every four murders compared with one roughly every two murders in Upper more than one detective per murder in Lower Manhattan
# New stripped sentence =  [[3, 'lobbies']] [] [[3, 'VBab']] [[3, 'CCab']]
# Origial sentence connotation=  [[3, 'lobbies'], [6, 'family'], [7, 'apartments'], [9, 'methadone'], [10, 'clinics'], [12, 'art']] [[13, 'studios']]
# [] [[1, 'In   lobbies']] [] []
# New stripped sentence =  [[1, 'family'], [2, 'apartments'], [4, 'methadone'], [5, 'clinics']] [] [[5, 'VBab']] [[5, 'CCab']]
# Origial sentence connotation=  [[3, 'lobbies'], [6, 'family'], [7, 'apartments'], [9, 'methadone'], [10, 'clinics'], [12, 'art']] [[13, 'studios']]
# [] [[1, 'In   lobbies'], [2, '  family apartments outside methadone clinics']] [] []
# New stripped sentence =  [[1, 'art'], [2, 'studios'], [3, 'people']] [[5, 'note'], [8, 'inequity']] [[4, 'take']] [[8, 'CCab']]
# Origial sentence connotation=  [[3, 'lobbies'], [6, 'family'], [7, 'apartments'], [9, 'methadone'], [10, 'clinics'], [12, 'art']] [[13, 'studios']]
# art studios people take note of the inequity
#
# [] [[1, 'In   lobbies'], [2, '  family apartments outside methadone clinics']] [] [[3, 'art studios people take note of the inequity\n']]
# <class 'TypeError'>
# New stripped sentence =  [[1, 'They'], [3, 'police'], [4, 'commanders'], [7, 'they'], [10, 'resources']] [[14, 'floodlight'], [18, 'block']] [[2, 'hear'], [5, 'explain'], [8, 'lack'], [12, 'place']] [[18, 'CCab']]
# Origial sentence connotation=  [[1, 'They'], [3, 'police'], [4, 'commanders'], [7, 'they'], [10, 'resources'], [14, 'floodlight'], [18, 'block']] [[22, 'officers'], [26, 'corner']]
# They hear police commanders explain that they lack the resources to place a floodlight on a dangerous block
# [] [] [] [[1, 'They hear police commanders explain that they lack the resources to place a floodlight on a dangerous block']]
# New stripped sentence =  [] [[3, 'officers'], [7, 'corner']] [[2, 'post']] [[7, 'CCab']]
# Origial sentence connotation=  [[1, 'They'], [3, 'police'], [4, 'commanders'], [7, 'they'], [10, 'resources'], [14, 'floodlight'], [18, 'block']] [[22, 'officers'], [26, 'corner']]
# [[2, 'to post officers at a   corner\n']] [] [] [[1, 'They hear police commanders explain that they lack the resources to place a floodlight on a dangerous block']]
# They hear police commanders explain that they lack the resources to place a floodlight on a dangerous block
# They to post officers at a corner
# New stripped sentence =  [[3, 'South'], [4, 'Bronx']] [] [[6, 'VBab']] [[6, 'CCab']]
# Origial sentence connotation=  [[3, 'South'], [4, 'Bronx'], [13, 'neighborhoods'], [15, 'it'], [18, 'United'], [19, 'States'], [21, 'contract'], [24, 'police'], [27, 'community']] [[30, 'tatters']]
# [] [[1, 'In the South Bronx as in']] [] []
# New stripped sentence =  [[3, 'SBab']] [] [[3, 'VBab']] [[3, 'CCab']]
# Origial sentence connotation=  [[3, 'South'], [4, 'Bronx'], [13, 'neighborhoods'], [15, 'it'], [18, 'United'], [19, 'States'], [21, 'contract'], [24, 'police'], [27, 'community']] [[30, 'tatters']]
# [] [[1, 'In the South Bronx as in'], [2, 'many predominantly black']] [] []
# New stripped sentence =  [[2, 'neighborhoods'], [4, 'it'], [7, 'United'], [8, 'States'], [10, 'contract'], [13, 'police']] [] [[13, 'VBab']] [[13, 'CCab']]
# Origial sentence connotation=  [[3, 'South'], [4, 'Bronx'], [13, 'neighborhoods'], [15, 'it'], [18, 'United'], [19, 'States'], [21, 'contract'], [24, 'police'], [27, 'community']] [[30, 'tatters']]
# [] [[1, 'In the South Bronx as in'], [2, 'many predominantly black'], [3, 'Hispanic neighborhoods like it in the United States the contract between the police']] [] []
# New stripped sentence =  [[2, 'community']] [[5, 'tatters']] [[3, 'is']] [[5, 'CCab']]
# Origial sentence connotation=  [[3, 'South'], [4, 'Bronx'], [13, 'neighborhoods'], [15, 'it'], [18, 'United'], [19, 'States'], [21, 'contract'], [24, 'police'], [27, 'community']] [[30, 'tatters']]
# the community is in tatters
#
# [] [[1, 'In the South Bronx as in'], [2, 'many predominantly black'], [3, 'Hispanic neighborhoods like it in the United States the contract between the police']] [] [[4, 'the community is in tatters\n']]
# <class 'TypeError'>
# New stripped sentence =  [[2, 'people'], [4, 'stories'], [6, 'crime'], [7, 'reports']] [] [[3, 'have'], [9, 'were'], [10, 'ignored']] [[10, 'CCab']]
# Origial sentence connotation=  [[2, 'people'], [4, 'stories'], [6, 'crime'], [7, 'reports'], [13, 'calls']] [[18, 'hours']]
# Some people have stories of crime reports that were ignored
# [] [] [] [[1, 'Some people have stories of crime reports that were ignored']]
# New stripped sentence =  [] [[5, 'SBab']] [[2, 'calls'], [4, 'went']] [[5, 'CCab']]
# Origial sentence connotation=  [[2, 'people'], [4, 'stories'], [6, 'crime'], [7, 'reports'], [13, 'calls']] [[18, 'hours']]
# [[2, '911 calls that went unanswered']] [] [] [[1, 'Some people have stories of crime reports that were ignored']]
# New stripped sentence =  [[1, 'hours']] [] [[1, 'VBab']] [[1, 'CCab']]
# Origial sentence connotation=  [[2, 'people'], [4, 'stories'], [6, 'crime'], [7, 'reports'], [13, 'calls']] [[18, 'hours']]
# Check hours [[18, 'hours']]
# [[2, '911 calls that went unanswered']] [] [[3, 'hours\n']] [[1, 'Some people have stories of crime reports that were ignored']]
# <class 'TypeError'>
# New stripped sentence =  [[1, 'Others']] [[6, 'call']] [[2, 'tell']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'Others'], [6, 'call'], [8, 'help'], [12, 'callers'], [18, 'charge']] [[22, 'hours']]
# Others tell of a 911 call
# [] [] [] [[1, 'Others tell of a 911 call']]
# New stripped sentence =  [[5, 'callers']] [] [[1, 'help'], [2, 'ending'], [6, 'arrest']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'Others'], [6, 'call'], [8, 'help'], [12, 'callers'], [18, 'charge']] [[22, 'hours']]
# ending help in the callers arrest
# [] [] [] [[1, 'Others tell of a 911 call'], [2, 'ending help in the callers arrest ']]
# New stripped sentence =  [[4, 'charge'], [8, 'hours']] [[13, 'cell']] [[5, 'leading'], [12, 'holding']] [[13, 'CCab']]
# Origial sentence connotation=  [[1, 'Others'], [6, 'call'], [8, 'help'], [12, 'callers'], [18, 'charge']] [[22, 'hours']]
# of a minor charge leading to 12 hours in a fetid holding cell
#
# [] [] [] [[1, 'Others tell of a 911 call'], [2, 'ending help in the callers arrest '], [3, 'of a minor charge leading to 12 hours in a fetid holding cell\n']]
# Others tell of a 911 call
# ending help in the callers arrest
# of a minor charge leading to 12 hours in a fetid holding cell
# New stripped sentence =  [[2, 'neighborhoods']] [[7, 'targets']] [[3, 'have'], [5, 'been']] [[7, 'CCab']]
# Origial sentence connotation=  [[2, 'neighborhoods'], [7, 'targets'], [10, 'tactics']] [[19, 'disorder']]
# Its neighborhoods have historically been prime targets
# [] [] [] [[1, 'Its neighborhoods have historically been prime targets']]
# New stripped sentence =  [[2, 'tactics']] [[11, 'disorder']] [[6, 'are'], [7, 'designed'], [9, 'ward']] [[11, 'CCab']]
# Origial sentence connotation=  [[2, 'neighborhoods'], [7, 'targets'], [10, 'tactics']] [[19, 'disorder']]
# aggressive tactics like    that are designed to ward off disorder
#
# [] [] [] [[1, 'Its neighborhoods have historically been prime targets'], [2, 'aggressive tactics like    that are designed to ward off disorder\n']]
# Its neighborhoods have historically been prime targets
# aggressive tactics like that are designed to ward off disorder
# New stripped sentence =  [[2, 'detectives'], [6, 'time'], [12, 'city']] [] [[4, 'have'], [14, 'answer']] [[14, 'CCab']]
# Origial sentence connotation=  [[3, 'detectives'], [4, 'there'], [7, 'time'], [13, 'city'], [18, 'blood']] [[22, 'crimes']]
# precinct detectives there have less time than anywhere else in the city to answer
# [] [] [] [[1, 'precinct detectives there have less time than anywhere else in the city to answer']]
# New stripped sentence =  [[2, 'blood']] [[6, 'crimes']] [[3, 'spilled']] [[6, 'CCab']]
# Origial sentence connotation=  [[3, 'detectives'], [4, 'there'], [7, 'time'], [13, 'city'], [18, 'blood']] [[22, 'crimes']]
# the blood spilled in violent crimes
#
# [] [] [] [[1, 'precinct detectives there have less time than anywhere else in the city to answer'], [2, 'the blood spilled in violent crimes\n']]
# precinct detectives there have less time than anywhere else in the city to answer
# the blood spilled in violent crimes
# New stripped sentence =  [[1, 'Gola'], [2, 'White'], [3, 'who'], [7, 'daughter'], [9, 'she']] [] [[4, 'was'], [10, 'was'], [11, 'shot']] [[11, 'CCab']]
# Origial sentence connotation=  [[1, 'Gola'], [2, 'White'], [3, 'who'], [7, 'daughter'], [9, 'she'], [16, 'playground']] [[18, 'summer']]
# Gola White who was beside her daughter when she was shot
# [] [] [] [[1, 'Gola White who was beside her daughter when she was shot']]
# New stripped sentence =  [[4, 'playground'], [6, 'summer'], [8, 'years'], [11, 'son'], [18, 'housing'], [19, 'project'], [24, 'safety'], [25, 'resources'], [27, 'she'], [32, 'Bronx'], [33, 'neighborhoods'], [35, 'hers'], [36, 'security'], [37, 'cameras'], [38, 'lights'], [39, 'locks']] [[41, 'police'], [42, 'officers']] [[1, 'killed'], [12, 'was'], [13, 'gunned'], [20, 'ticked'], [28, 'said'], [29, 'were'], [40, 'investigating']] [[42, 'CCab']]
# Origial sentence connotation=  [[1, 'Gola'], [2, 'White'], [3, 'who'], [7, 'daughter'], [9, 'she'], [16, 'playground']] [[18, 'summer']]
# in killed a playground this summer four years after her son was gunned down in the same housing project ticked off the public safety resources that she said were scant in Bronx neighborhoods like hers security cameras lights locks investigating police officers
# [] [] [] [[1, 'Gola White who was beside her daughter when she was shot'], [2, 'in killed a playground this summer four years after her son was gunned down in the same housing project ticked off the public safety resources that she said were scant in Bronx neighborhoods like hers security cameras lights locks investigating police officers ']]
# Gola White who was beside her daughter when she was shot
# in killed a playground this summer four years after her son was gunned down in the same housing project ticked off the public safety resources that she said were scant in Bronx neighborhoods like hers security cameras lights locks investigating police officers
# New stripped sentence =  [[2, 'homicides'], [7, 'precinct'], [9, 'year'], [16, 'strain'], [17, 'detectives']] [] [[17, 'VBab']] [[17, 'CCab']]
# Origial sentence connotation=  [[2, 'homicides'], [7, 'precinct'], [9, 'year'], [17, 'detectives'], [20, 'they']] [[24, 'half']]
# [] [[1, 'The homicides     14 in the precinct this year up from nine in 2015     strain detectives']] [] []
# New stripped sentence =  [[2, 'they'], [6, 'half'], [8, 'them'], [11, 'year']] [[17, 'law'], [21, 'hands']] [[3, 'go'], [9, 'have'], [13, 'look'], [15, 'take']] [[21, 'CCab']]
# Origial sentence connotation=  [[2, 'homicides'], [7, 'precinct'], [9, 'year'], [17, 'detectives'], [20, 'they']] [[24, 'half']]
# when they go unsolved as half of them have this year some look to take the law into their own hands
#
# [] [[1, 'The homicides     14 in the precinct this year up from nine in 2015     strain detectives']] [] [[2, 'when they go unsolved as half of them have this year some look to take the law into their own hands\n']]
# when they go unsolved as half of them have this year some look to take the law into their own hands
# The homicides 14 in the precinct this year up from nine in 2015 strain detectives when they go unsolved as half of them have this some look to take the law into their own hands
# New stripped sentence =  [[2, 'hundreds'], [4, 'conversations']] [[7, 'relatives']] [[6, 'grieving']] [[7, 'CCab']]
# Origial sentence connotation=  [[2, 'hundreds'], [4, 'conversations'], [7, 'relatives'], [9, 'friends'], [10, 'witnesses'], [12, 'police'], [13, 'officers'], [16, 'forces'], [20, 'murder'], [23, 'place'], [27, 'Precinct'], [30, 'merciless'], [31, 'gang'], [34, 'illness'], [35, 'drugs'], [38, 'memories']] [[40, 'feuds']]
# From hundreds of conversations with grieving relatives
# [] [] [] [[1, 'From hundreds of conversations with grieving relatives']]
# New stripped sentence =  [[1, 'friends'], [2, 'witnesses']] [] [[2, 'VBab']] [[2, 'CCab']]
# Origial sentence connotation=  [[2, 'hundreds'], [4, 'conversations'], [7, 'relatives'], [9, 'friends'], [10, 'witnesses'], [12, 'police'], [13, 'officers'], [16, 'forces'], [20, 'murder'], [23, 'place'], [27, 'Precinct'], [30, 'merciless'], [31, 'gang'], [34, 'illness'], [35, 'drugs'], [38, 'memories']] [[40, 'feuds']]
# [] [[2, 'friends witnesses']] [] [[1, 'From hundreds of conversations with grieving relatives']]
# New stripped sentence =  [[1, 'police'], [2, 'officers'], [5, 'forces'], [9, 'murder'], [12, 'place'], [16, 'Precinct'], [19, 'merciless'], [20, 'gang']] [[23, 'illness'], [24, 'drugs']] [[7, 'flare'], [17, 'become'], [21, 'codes']] [[24, 'CCab']]
# Origial sentence connotation=  [[2, 'hundreds'], [4, 'conversations'], [7, 'relatives'], [9, 'friends'], [10, 'witnesses'], [12, 'police'], [13, 'officers'], [16, 'forces'], [20, 'murder'], [23, 'place'], [27, 'Precinct'], [30, 'merciless'], [31, 'gang'], [34, 'illness'], [35, 'drugs'], [38, 'memories']] [[40, 'feuds']]
# police officers the social forces that flare into murder in a place like the 40th Precinct become clearer merciless gang codes mental illness drugs
# [] [[2, 'friends witnesses']] [] [[1, 'From hundreds of conversations with grieving relatives'], [3, 'police officers the social forces that flare into murder in a place like the 40th Precinct become clearer merciless gang codes mental illness drugs']]
# New stripped sentence =  [[2, 'memories'], [4, 'feuds'], [9, 'officers']] [] [[6, 'simmered'], [10, 'view']] [[10, 'CCab']]
# Origial sentence connotation=  [[2, 'hundreds'], [4, 'conversations'], [7, 'relatives'], [9, 'friends'], [10, 'witnesses'], [12, 'police'], [13, 'officers'], [16, 'forces'], [20, 'murder'], [23, 'place'], [27, 'Precinct'], [30, 'merciless'], [31, 'gang'], [34, 'illness'], [35, 'drugs'], [38, 'memories']] [[40, 'feuds']]
# long memories of feuds that simmered out of officers view
#
# [] [[2, 'friends witnesses']] [] [[1, 'From hundreds of conversations with grieving relatives'], [3, 'police officers the social forces that flare into murder in a place like the 40th Precinct become clearer merciless gang codes mental illness drugs'], [4, 'long memories of feuds that simmered out of officers view\n']]
# From hundreds of conversations with grieving relatives
# police officers the social forces that flare into murder in a place like the 40th Precinct become clearer merciless gang codes mental illness drugs
# long memories of feuds that simmered out of officers view
# friends witnesses police officers the social forces that flare into murder in a place like the 40th Precinct become clearer merciless codes mental illness drugs
# New stripped sentence =  [[2, 'reasons'], [4, 'murders'], [12, 'fear'], [14, 'retribution'], [15, 'victims']] [[17, 'secrets'], [20, 'graves']] [[5, 'will'], [7, 'be'], [8, 'solved'], [10, 'emerge'], [11, 'paralyzing'], [16, 'carrying']] [[20, 'CCab']]
# Origial sentence connotation=  [[2, 'reasons'], [4, 'murders'], [12, 'fear'], [14, 'retribution'], [15, 'victims'], [17, 'secrets'], [20, 'graves'], [23, 'casework']] [[26, 'detectives']]
# The reasons some murders will never be solved also emerge paralyzing fear of retribution victims carrying secrets to their graves
# [] [] [] [[1, 'The reasons some murders will never be solved also emerge paralyzing fear of retribution victims carrying secrets to their graves']]
# New stripped sentence =  [[2, 'casework'], [5, 'detectives'], [10, 'hopes'], [13, 'break']] [] [[4, 'forces'], [7, 'move'], [14, 'will'], [15, 'come']] [[16, 'CCab']]
# Origial sentence connotation=  [[2, 'reasons'], [4, 'murders'], [12, 'fear'], [14, 'retribution'], [15, 'victims'], [17, 'secrets'], [20, 'graves'], [23, 'casework']] [[26, 'detectives']]
# relentless casework that forces detectives to move on in hopes that a break will come later
#
# [] [] [] [[1, 'The reasons some murders will never be solved also emerge paralyzing fear of retribution victims carrying secrets to their graves'], [2, 'relentless casework that forces detectives to move on in hopes that a break will come later\n']]
# The reasons some murders will never be solved also emerge paralyzing fear of retribution victims carrying secrets to their graves
# relentless casework that forces detectives to move on in hopes that a break will come later
# New stripped sentence =  [[1, 'Detectives'], [2, 'phones']] [[6, 'tips']] [[4, 'ring']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'Detectives'], [2, 'phones'], [6, 'tips'], [8, 'officers']] [[12, 'witnesses']]
# Detectives phones rarely ring with tips
# [] [] [] [[1, 'Detectives phones rarely ring with tips']]
# New stripped sentence =  [[1, 'officers'], [5, 'witnesses'], [6, 'who']] [] [[2, 'grow'], [3, 'embittered'], [7, 'will'], [9, 'cooperate']] [[9, 'CCab']]
# Origial sentence connotation=  [[1, 'Detectives'], [2, 'phones'], [6, 'tips'], [8, 'officers']] [[12, 'witnesses']]
# officers grow embittered with witnesses who will not cooperate
#
# [] [] [] [[1, 'Detectives phones rarely ring with tips'], [2, 'officers grow embittered with witnesses who will not cooperate\n']]
# Detectives phones rarely ring with tips
# officers grow embittered with witnesses who will not cooperate
# New stripped sentence =  [[3, 'meantime'], [5, 'victims'], [6, 'friends']] [[10, 'investigations']] [[7, 'conduct']] [[10, 'CCab']]
# Origial sentence connotation=  [[3, 'meantime'], [5, 'victims'], [6, 'friends'], [10, 'investigations'], [12, 'talk'], [16, 'stash'], [17, 'gun'], [20, 'wheel'], [24, 'mothers']] [[25, 'apartment']]
# In the meantime a victims friends conduct their own investigations
# [] [] [] [[1, 'In the meantime a victims friends conduct their own investigations']]
# New stripped sentence =  [[1, 'talk']] [[5, 'stash'], [6, 'gun'], [9, 'wheel']] [[3, 'grabbing']] [[10, 'CCab']]
# Origial sentence connotation=  [[3, 'meantime'], [5, 'victims'], [6, 'friends'], [10, 'investigations'], [12, 'talk'], [16, 'stash'], [17, 'gun'], [20, 'wheel'], [24, 'mothers']] [[25, 'apartment']]
# talk of grabbing a stash gun from a wheel well
# [] [] [] [[1, 'In the meantime a victims friends conduct their own investigations'], [2, 'talk of grabbing a stash gun from a wheel well']]
# New stripped sentence =  [[2, 'mothers'], [3, 'apartment'], [5, 'they']] [[8, 'suspect']] [[6, 'find']] [[8, 'CCab']]
# Origial sentence connotation=  [[3, 'meantime'], [5, 'victims'], [6, 'friends'], [10, 'investigations'], [12, 'talk'], [16, 'stash'], [17, 'gun'], [20, 'wheel'], [24, 'mothers']] [[25, 'apartment']]
# a mothers apartment when they find their suspect
#
# [] [] [] [[1, 'In the meantime a victims friends conduct their own investigations'], [2, 'talk of grabbing a stash gun from a wheel well'], [3, 'a mothers apartment when they find their suspect\n']]
# In the meantime a victims friends conduct their own investigations
# talk of grabbing a stash gun from a wheel well
# a mothers apartment when they find their suspect
# New stripped sentence =  [[3, 'chasm'], [6, 'police']] [] [[6, 'VBab']] [[6, 'CCab']]
# Origial sentence connotation=  [[3, 'chasm'], [6, 'police'], [9, 'community'], [10, 'gangs'], [12, 'gun']] [[13, 'violence']]
# [] [[1, 'In the chasm between the police']] [] []
# New stripped sentence =  [[2, 'community'], [3, 'gangs']] [] [[3, 'VBab']] [[3, 'CCab']]
# Origial sentence connotation=  [[3, 'chasm'], [6, 'police'], [9, 'community'], [10, 'gangs'], [12, 'gun']] [[13, 'violence']]
# [] [[1, 'In the chasm between the police'], [2, 'the community gangs']] [] []
# New stripped sentence =  [[1, 'gun'], [2, 'violence'], [3, 'flourish']] [] [[3, 'VBab']] [[3, 'CCab']]
# Origial sentence connotation=  [[3, 'chasm'], [6, 'police'], [9, 'community'], [10, 'gangs'], [12, 'gun']] [[13, 'violence']]
# [] [[1, 'In the chasm between the police'], [2, 'the community gangs'], [3, 'gun violence flourish\n']] [] []
# <class 'TypeError'>
# New stripped sentence =  [[1, 'Parents']] [[6, 'families'], [8, 'drug'], [9, 'crews'], [10, 'threats']] [[2, 'try'], [4, 'protect']] [[10, 'CCab']]
# Origial sentence connotation=  [[1, 'Parents'], [6, 'families'], [8, 'drug'], [9, 'crews'], [10, 'threats'], [12, 'officers'], [17, 'residue'], [19, 'years'], [21, 'mistrust'], [25, 'communities']] [[27, 'they']]
# Parents try to protect their families from drug crews threats
# [] [] [] [[1, 'Parents try to protect their families from drug crews threats']]
# New stripped sentence =  [[1, 'officers']] [[6, 'residue'], [8, 'years'], [10, 'mistrust']] [[2, 'work'], [4, 'overcome']] [[10, 'CCab']]
# Origial sentence connotation=  [[1, 'Parents'], [6, 'families'], [8, 'drug'], [9, 'crews'], [10, 'threats'], [12, 'officers'], [17, 'residue'], [19, 'years'], [21, 'mistrust'], [25, 'communities']] [[27, 'they']]
# officers work to overcome the residue of years of mistrust
# [] [] [] [[1, 'Parents try to protect their families from drug crews threats'], [2, 'officers work to overcome the residue of years of mistrust']]
# New stripped sentence =  [[3, 'communities'], [5, 'they']] [[12, 'call']] [[1, 'understaffing'], [7, 'go'], [8, 'racing']] [[15, 'CCab']]
# Origial sentence connotation=  [[1, 'Parents'], [6, 'families'], [8, 'drug'], [9, 'crews'], [10, 'threats'], [12, 'officers'], [17, 'residue'], [19, 'years'], [21, 'mistrust'], [25, 'communities']] [[27, 'they']]
# in understaffing communities where they still go racing from one 911 call to the next
# [] [] [] [[1, 'Parents try to protect their families from drug crews threats'], [2, 'officers work to overcome the residue of years of mistrust'], [3, 'in understaffing communities where they still go racing from one 911 call to the next ']]
# Parents try to protect their families from drug crews threats
# officers work to overcome the residue of years of mistrust
# in understaffing communities where they still go racing from one 911 call to the next
# New stripped sentence =  [[1, 'He'], [5, 'end'], [9, 'hallway']] [[13, 'needles'], [15, 'dope'], [16, 'bags']] [[2, 'lived'], [10, 'strewn']] [[16, 'CCab']]
# Origial sentence connotation=  [[1, 'He'], [5, 'end'], [9, 'hallway'], [13, 'needles'], [15, 'dope'], [16, 'bags']] [[19, 'Hennessy'], [20, 'bottles']]
# He lived at the end of a long hallway strewn with hypodermic needles empty dope bags
# [] [] [] [[1, 'He lived at the end of a long hallway strewn with hypodermic needles empty dope bags']]
# New stripped sentence =  [] [[2, 'Hennessy'], [3, 'bottles']] [[1, 'discarded']] [[3, 'CCab']]
# Origial sentence connotation=  [[1, 'He'], [5, 'end'], [9, 'hallway'], [13, 'needles'], [15, 'dope'], [16, 'bags']] [[19, 'Hennessy'], [20, 'bottles']]
# [[2, 'discarded Hennessy bottles\n']] [] [] [[1, 'He lived at the end of a long hallway strewn with hypodermic needles empty dope bags']]
# He lived at the end of a long hallway strewn with hypodermic needles empty dope bags
# He discarded Hennessy bottles
# New stripped sentence =  [[4, 'men'], [5, 'who'], [11, 'subset'], [14, 'Bloods'], [15, 'gang'], [18, 'it'], [20, 'drug'], [21, 'market']] [[23, 'marijuana']] [[6, 'spoke'], [8, 'being'], [16, 'had'], [17, 'made'], [22, 'slinging']] [[23, 'CCab']]
# Origial sentence connotation=  [[4, 'men'], [5, 'who'], [11, 'subset'], [14, 'Bloods'], [15, 'gang'], [18, 'it'], [20, 'drug'], [21, 'market'], [23, 'marijuana'], [25, 'cocaine'], [27, 'regulars'], [29, 'firearms']] [[32, 'smoke'], [35, 'Fernandez']]
# A   young men who spoke of being in a subset of the Bloods gang had made it their drug market slinging marijuana
# [] [] [] [[1, 'A   young men who spoke of being in a subset of the Bloods gang had made it their drug market slinging marijuana']]
# New stripped sentence =  [[1, 'cocaine'], [3, 'regulars']] [[5, 'firearms']] [[4, 'flashing']] [[5, 'CCab']]
# Origial sentence connotation=  [[4, 'men'], [5, 'who'], [11, 'subset'], [14, 'Bloods'], [15, 'gang'], [18, 'it'], [20, 'drug'], [21, 'market'], [23, 'marijuana'], [25, 'cocaine'], [27, 'regulars'], [29, 'firearms']] [[32, 'smoke'], [35, 'Fernandez']]
# cocaine to regulars flashing firearms
# [] [] [] [[1, 'A   young men who spoke of being in a subset of the Bloods gang had made it their drug market slinging marijuana'], [2, 'cocaine to regulars flashing firearms']]
# New stripped sentence =  [] [[2, 'smoke'], [5, 'Fernandez'], [6, 'apartment']] [[1, 'blowing']] [[6, 'CCab']]
# Origial sentence connotation=  [[4, 'men'], [5, 'who'], [11, 'subset'], [14, 'Bloods'], [15, 'gang'], [18, 'it'], [20, 'drug'], [21, 'market'], [23, 'marijuana'], [25, 'cocaine'], [27, 'regulars'], [29, 'firearms']] [[32, 'smoke'], [35, 'Fernandez']]
# [[3, 'blowing smoke into the Fernandez apartment\n']] [] [] [[1, 'A   young men who spoke of being in a subset of the Bloods gang had made it their drug market slinging marijuana'], [2, 'cocaine to regulars flashing firearms']]
# A young men who spoke of being in a subset of the Bloods gang had made it their drug market slinging marijuana
# cocaine to regulars flashing firearms
# cocaine blowing smoke into the Fernandez apartment
# New stripped sentence =  [[1, 'It']] [[8, 'communities'], [11, 'country']] [[2, 'is']] [[11, 'CCab']]
# Origial sentence connotation=  [[1, 'It'], [8, 'communities'], [11, 'country'], [15, 'men']] [[18, 'way']]
# It is also one of the poorest communities in the country
# [] [] [] [[1, 'It is also one of the poorest communities in the country']]
# New stripped sentence =  [[3, 'men']] [[6, 'way'], [9, 'markets']] [[4, 'find']] [[9, 'CCab']]
# Origial sentence connotation=  [[1, 'It'], [8, 'communities'], [11, 'country'], [15, 'men']] [[18, 'way']]
# many young men find their way into underground markets
#
# [] [] [] [[1, 'It is also one of the poorest communities in the country'], [2, 'many young men find their way into underground markets\n']]
# It is also one of the poorest communities in the country
# many young men find their way into underground markets
# New stripped sentence =  [[2, 'he'], [8, 'Lower'], [9, 'East'], [10, 'Side'], [11, 'he'], [14, 'bicycle'], [18, 'customers'], [21, 'drug'], [22, 'dealers'], [23, 'he']] [] [[3, 'was'], [4, 'growing'], [12, 'rode'], [24, 'worked']] [[24, 'CCab']]
# Origial sentence connotation=  [[2, 'he'], [8, 'Lower'], [9, 'East'], [10, 'Side'], [11, 'he'], [14, 'bicycle'], [18, 'customers'], [21, 'drug'], [22, 'dealers'], [23, 'he']] [[28, 'payments'], [31, 'backpack']]
# When he was growing up on the Lower East Side he rode his bicycle around to the customers of the drug dealers he worked
# [] [] [] [[1, 'When he was growing up on the Lower East Side he rode his bicycle around to the customers of the drug dealers he worked']]
# New stripped sentence =  [] [[2, 'payments'], [5, 'backpack']] [[1, 'collected']] [[5, 'CCab']]
# Origial sentence connotation=  [[2, 'he'], [8, 'Lower'], [9, 'East'], [10, 'Side'], [11, 'he'], [14, 'bicycle'], [18, 'customers'], [21, 'drug'], [22, 'dealers'], [23, 'he']] [[28, 'payments'], [31, 'backpack']]
# [[2, 'collected payments in a backpack\n']] [] [] [[1, 'When he was growing up on the Lower East Side he rode his bicycle around to the customers of the drug dealers he worked']]
# When he was growing up on the Lower East Side he rode his bicycle around to the customers of the drug dealers he worked
# he collected payments in a backpack
# New stripped sentence =  [[4, 'life'], [5, 'he']] [[8, 'tech'], [9, 'maintenance'], [10, 'job']] [[2, 'leaving'], [6, 'got']] [[10, 'CCab']]
# Origial sentence connotation=  [[4, 'life'], [5, 'he'], [8, 'tech'], [9, 'maintenance'], [10, 'job'], [13, 'years']] [[18, 'Betances'], [19, 'Houses'], [22, 'wife'], [24, 'daughter']]
# After leaving that life he got a tech maintenance job
# [] [] [] [[1, 'After leaving that life he got a tech maintenance job']]
# New stripped sentence =  [[2, 'years']] [[7, 'Betances'], [8, 'Houses'], [11, 'wife']] [[4, 'moved']] [[11, 'CCab']]
# Origial sentence connotation=  [[4, 'life'], [5, 'he'], [8, 'tech'], [9, 'maintenance'], [10, 'job'], [13, 'years']] [[18, 'Betances'], [19, 'Houses'], [22, 'wife'], [24, 'daughter']]
# three years ago moved into the Betances Houses with his wife
# [] [] [] [[1, 'After leaving that life he got a tech maintenance job'], [2, 'three years ago moved into the Betances Houses with his wife']]
# New stripped sentence =  [[1, 'daughter']] [] [[3, 'VBab']] [[3, 'CCab']]
# Origial sentence connotation=  [[4, 'life'], [5, 'he'], [8, 'tech'], [9, 'maintenance'], [10, 'job'], [13, 'years']] [[18, 'Betances'], [19, 'Houses'], [22, 'wife'], [24, 'daughter']]
# Check daughter [[18, 'Betances'], [19, 'Houses'], [22, 'wife'], [24, 'daughter']]
# [] [] [[3, 'daughter now 11\n']] [[1, 'After leaving that life he got a tech maintenance job'], [2, 'three years ago moved into the Betances Houses with his wife']]
# After leaving that life he got a tech maintenance job
# three years ago moved into the Betances Houses with his wife
# three years ago moved into the Betances Houses with his daughter now 11
# New stripped sentence =  [[1, 'He'], [4, 'choices'], [7, 'help'], [10, 'drug'], [11, 'crew']] [[14, 'police']] [[2, 'had'], [6, 'get'], [12, 'call']] [[14, 'CCab']]
# Origial sentence connotation=  [[1, 'He'], [4, 'choices'], [7, 'help'], [10, 'drug'], [11, 'crew'], [14, 'police'], [16, 'help'], [18, 'risk'], [22, 'snitch']] [[27, 'Lower'], [28, 'East'], [29, 'Side'], [30, 'bosses'], [32, 'muscle'], [34, 'risk'], [35, 'violence']]
# He had two choices to get help with the drug crew call the police
# [] [] [] [[1, 'He had two choices to get help with the drug crew call the police']]
# New stripped sentence =  [[1, 'help']] [] [[1, 'VBab']] [[1, 'CCab']]
# Origial sentence connotation=  [[1, 'He'], [4, 'choices'], [7, 'help'], [10, 'drug'], [11, 'crew'], [14, 'police'], [16, 'help'], [18, 'risk'], [22, 'snitch']] [[27, 'Lower'], [28, 'East'], [29, 'Side'], [30, 'bosses'], [32, 'muscle'], [34, 'risk'], [35, 'violence']]
# [] [[2, 'help']] [] [[1, 'He had two choices to get help with the drug crew call the police']]
# New stripped sentence =  [[1, 'risk']] [[5, 'snitch']] [[2, 'being'], [3, 'labeled']] [[5, 'CCab']]
# Origial sentence connotation=  [[1, 'He'], [4, 'choices'], [7, 'help'], [10, 'drug'], [11, 'crew'], [14, 'police'], [16, 'help'], [18, 'risk'], [22, 'snitch']] [[27, 'Lower'], [28, 'East'], [29, 'Side'], [30, 'bosses'], [32, 'muscle'], [34, 'risk'], [35, 'violence']]
# risk being labeled a snitch
# [] [[2, 'help']] [] [[1, 'He had two choices to get help with the drug crew call the police'], [3, 'risk being labeled a snitch']]
# New stripped sentence =  [] [[4, 'Lower'], [5, 'East'], [6, 'Side'], [7, 'bosses']] [[1, 'call']] [[7, 'CCab']]
# Origial sentence connotation=  [[1, 'He'], [4, 'choices'], [7, 'help'], [10, 'drug'], [11, 'crew'], [14, 'police'], [16, 'help'], [18, 'risk'], [22, 'snitch']] [[27, 'Lower'], [28, 'East'], [29, 'Side'], [30, 'bosses'], [32, 'muscle'], [34, 'risk'], [35, 'violence']]
# [[4, 'call his old Lower East Side bosses']] [[2, 'help']] [] [[1, 'He had two choices to get help with the drug crew call the police'], [3, 'risk being labeled a snitch']]
# New stripped sentence =  [[1, 'muscle']] [] [[1, 'VBab']] [[1, 'CCab']]
# Origial sentence connotation=  [[1, 'He'], [4, 'choices'], [7, 'help'], [10, 'drug'], [11, 'crew'], [14, 'police'], [16, 'help'], [18, 'risk'], [22, 'snitch']] [[27, 'Lower'], [28, 'East'], [29, 'Side'], [30, 'bosses'], [32, 'muscle'], [34, 'risk'], [35, 'violence']]
# Check muscle [[27, 'Lower'], [28, 'East'], [29, 'Side'], [30, 'bosses'], [32, 'muscle'], [34, 'risk'], [35, 'violence']]
# [[4, 'call his old Lower East Side bosses']] [[2, 'help']] [[5, 'muscle']] [[1, 'He had two choices to get help with the drug crew call the police'], [3, 'risk being labeled a snitch']]
# New stripped sentence =  [[1, 'risk'], [2, 'violence']] [] [[2, 'VBab']] [[2, 'CCab']]
# Origial sentence connotation=  [[1, 'He'], [4, 'choices'], [7, 'help'], [10, 'drug'], [11, 'crew'], [14, 'police'], [16, 'help'], [18, 'risk'], [22, 'snitch']] [[27, 'Lower'], [28, 'East'], [29, 'Side'], [30, 'bosses'], [32, 'muscle'], [34, 'risk'], [35, 'violence']]
# Check risk [[27, 'Lower'], [28, 'East'], [29, 'Side'], [30, 'bosses'], [32, 'muscle'], [34, 'risk'], [35, 'violence']]
# [[4, 'call his old Lower East Side bosses']] [[2, 'help']] [[5, 'muscle'], [6, 'risk violence\n']] [[1, 'He had two choices to get help with the drug crew call the police'], [3, 'risk being labeled a snitch']]
# He had two choices to get help with the drug crew call the police
# risk being labeled a snitch
# risk call his old Lower East Side bosses
# risk call his old Lower East Side muscle
# risk call his old Lower East Side risk violence
# help being labeled a snitch
# New stripped sentence =  [[1, 'SBab']] [] [[1, 'VBab']] [[1, 'CCab']]
# Origial sentence connotation=  [[4, 'he'], [9, 'substation'], [10, 'Police'], [11, 'Service'], [12, 'Area']] [[17, 'protection']]
# [] [[1, 'Again']] [] []
# New stripped sentence =  [[2, 'he']] [[7, 'substation'], [8, 'Police'], [9, 'Service'], [10, 'Area']] [[3, 'walked']] [[11, 'CCab']]
# Origial sentence connotation=  [[4, 'he'], [9, 'substation'], [10, 'Police'], [11, 'Service'], [12, 'Area']] [[17, 'protection']]
# again he walked into a local substation Police Service Area 7
# [] [[1, 'Again']] [] [[2, 'again he walked into a local substation Police Service Area 7']]
# New stripped sentence =  [[1, 'SBab']] [] [[1, 'asked']] [[1, 'CCab']]
# Origial sentence connotation=  [[4, 'he'], [9, 'substation'], [10, 'Police'], [11, 'Service'], [12, 'Area']] [[17, 'protection']]
# [] [[1, 'Again']] [] [[2, 'again he walked into a local substation Police Service Area 7'], [3, 'asked']]
# New stripped sentence =  [[1, 'protection']] [] [[1, 'VBab']] [[1, 'CCab']]
# Origial sentence connotation=  [[4, 'he'], [9, 'substation'], [10, 'Police'], [11, 'Service'], [12, 'Area']] [[17, 'protection']]
# Check protection [[17, 'protection']]
# [] [[1, 'Again']] [[4, 'protection\n']] [[2, 'again he walked into a local substation Police Service Area 7'], [3, 'asked']]
# <class 'TypeError'>
# New stripped sentence =  [[1, 'Mr'], [2, 'Fernandez']] [] [[2, 'VBab']] [[2, 'CCab']]
# Origial sentence connotation=  [[1, 'Mr'], [2, 'Fernandez'], [5, 'wife']] [[8, 'headaches']]
# [] [[1, 'Mr Fernandez']] [] []
# New stripped sentence =  [[2, 'wife']] [[5, 'headaches']] [[3, 'got']] [[5, 'CCab']]
# Origial sentence connotation=  [[1, 'Mr'], [2, 'Fernandez'], [5, 'wife']] [[8, 'headaches']]
# ...
# Origial sentence connotation=  [[3, 'PSA'], [8, 'anything']] [[9, 'he']]
# PSA 7 wont do anything he wrote referring to the local substation
#
# [] [[1, '40th']] [] [[2, 'PSA 7 wont do anything he wrote referring to the local substation\n']]
# PSA 7 wont do anything he wrote referring to the local substation
# 40th PSA 7 wont do anything wrote referring to t local substation
# New stripped sentence =  [[3, 'substation'], [4, 'commander'], [5, 'Deputy'], [6, 'Inspector'], [7, 'Jerry'], [8, 'OSullivan']] [] [[8, 'VBab']] [[8, 'CCab']]
# Origial sentence connotation=  [[3, 'substation'], [4, 'commander'], [5, 'Deputy'], [6, 'Inspector'], [7, 'Jerry'], [8, 'OSullivan'], [11, 'Bronx']] [[12, 'narcotics']]
# [] [[1, 'The local substation commander Deputy Inspector Jerry OSullivan']] [] []
# New stripped sentence =  [[2, 'Bronx'], [3, 'narcotics'], [4, 'unit']] [[9, 'complaints']] [[5, 'were'], [6, 'alerted']] [[9, 'CCab']]
# Origial sentence connotation=  [[3, 'substation'], [4, 'commander'], [5, 'Deputy'], [6, 'Inspector'], [7, 'Jerry'], [8, 'OSullivan'], [11, 'Bronx']] [[12, 'narcotics']]
# the Bronx narcotics unit were alerted to the complaints
#
# [] [[1, 'The local substation commander Deputy Inspector Jerry OSullivan']] [] [[2, 'the Bronx narcotics unit were alerted to the complaints\n']]
# the Bronx narcotics unit were alerted to the complaints
# The local substation commander Deputy Inspector Jerry OSullivan the Bronx narcotics were alerted to the complaints
# New stripped sentence =  [[1, 'Mr'], [2, 'Fernandez'], [4, 'he']] [[8, 'them']] [[3, 'said'], [6, 'heard']] [[8, 'CCab']]
# Origial sentence connotation=  [[2, 'Mr'], [3, 'Fernandez']] [[5, 'he']]
# Mr Fernandez said he never heard from them
#
# [] [] [] [[1, 'Mr Fernandez said he never heard from them\n']]
# Mr Fernandez said he never heard from them
# New stripped sentence =  [[1, 'he'], [6, 'street'], [7, 'instincts']] [[11, 'family']] [[2, 'relied'], [9, 'protect']] [[11, 'CCab']]
# Origial sentence connotation=  [[2, 'he'], [7, 'street']] [[8, 'instincts']]
# he relied on his own street instincts to protect his family
#
# [] [] [] [[1, 'he relied on his own street instincts to protect his family\n']]
# he relied on his own street instincts to protect his family
# New stripped sentence =  [[2, 'activity']] [[4, 'briefly']] [[3, 'quieted']] [[4, 'CCab']]
# Origial sentence connotation=  [[2, 'activity'], [4, 'briefly'], [6, 'it']] [[11, 'men']]
# The activity quieted briefly
# [] [] [] [[1, 'The activity quieted briefly']]
# New stripped sentence =  [[1, 'it'], [6, 'men'], [9, 'room'], [12, 'womans'], [13, 'apartment'], [14, 'upstairs'], [15, 'Mr'], [16, 'Fernandez'], [20, 'man'], [21, 'who'], [22, 'he']] [[26, 'boss'], [29, 'operation']] [[2, 'returned'], [7, 'rented'], [17, 'approached'], [23, 'learned'], [24, 'was']] [[29, 'CCab']]
# Origial sentence connotation=  [[2, 'activity'], [4, 'briefly'], [6, 'it']] [[11, 'men']]
# it returned after the young men rented a room in a womans apartment upstairs Mr Fernandez approached a different man who he learned was the boss of the operation
#
# [] [] [] [[1, 'The activity quieted briefly'], [2, 'it returned after the young men rented a room in a womans apartment upstairs Mr Fernandez approached a different man who he learned was the boss of the operation\n']]
# The activity quieted briefly
# it returned after the young men rented a room in a womans apartment upstairs Mr Fernandez approached a different man who he learned was the boss of the operation
# New stripped sentence =  [[2, 'weeks'], [5, 'dealing']] [] [[5, 'VBab']] [[5, 'CCab']]
# Origial sentence connotation=  [[3, 'weeks'], [6, 'dealing'], [9, 'harassment']] []
# [] [[1, 'two weeks later the dealing']] [] []
# New stripped sentence =  [[2, 'harassment']] [] [[3, 'resumed']] [[3, 'CCab']]
# Origial sentence connotation=  [[3, 'weeks'], [6, 'dealing'], [9, 'harassment']] []
# the harassment resumed
#
# [] [[1, 'two weeks later the dealing']] [] [[2, 'the harassment resumed\n']]
# the harassment resumed
# two weeks later the dealing the resumed
# New stripped sentence =  [[2, 'he'], [7, 'Lower'], [8, 'East'], [9, 'Side'], [10, 'bosses'], [11, 'who'], [13, 'men']] [[17, 'wife']] [[3, 'went'], [12, 'hired'], [15, 'trail']] [[17, 'CCab']]
# Origial sentence connotation=  [[2, 'he'], [7, 'Lower'], [8, 'East'], [9, 'Side'], [10, 'bosses'], [11, 'who'], [13, 'men'], [17, 'wife'], [19, 'daughter'], [22, 'way'], [26, 'building'], [30, 'they']] [[32, 'it']]
# So he went to his old Lower East Side bosses who hired men to trail his wife
# [] [] [] [[1, 'So he went to his old Lower East Side bosses who hired men to trail his wife']]
# New stripped sentence =  [[1, 'daughter'], [4, 'way'], [8, 'building']] [] [[8, 'VBab']] [[8, 'CCab']]
# Origial sentence connotation=  [[2, 'he'], [7, 'Lower'], [8, 'East'], [9, 'Side'], [10, 'bosses'], [11, 'who'], [13, 'men'], [17, 'wife'], [19, 'daughter'], [22, 'way'], [26, 'building'], [30, 'they']] [[32, 'it']]
# [] [[2, 'daughter on their way out of the building']] [] [[1, 'So he went to his old Lower East Side bosses who hired men to trail his wife']]
# New stripped sentence =  [[3, 'they']] [[5, 'it'], [8, 'school']] [[1, 'make'], [4, 'made']] [[8, 'CCab']]
# Origial sentence connotation=  [[2, 'he'], [7, 'Lower'], [8, 'East'], [9, 'Side'], [10, 'bosses'], [11, 'who'], [13, 'men'], [17, 'wife'], [19, 'daughter'], [22, 'way'], [26, 'building'], [30, 'they']] [[32, 'it']]
# sure make they made it safely to school
# [] [[2, 'daughter on their way out of the building']] [] [[1, 'So he went to his old Lower East Side bosses who hired men to trail his wife'], [3, 'sure make they made it safely to school ']]
# So he went to his old Lower East Side bosses who hired men to trail his wife
# sure make they made it safely to school
# daughter on their way out of the building sure make made it safely to school
# New stripped sentence =  [[1, 'He']] [[5, 'bulletproof'], [6, 'vests']] [[3, 'bought']] [[6, 'CCab']]
# Origial sentence connotation=  [[1, 'He']] [[5, 'bulletproof'], [6, 'vests']]
# He also bought two bulletproof vests
# [] [] [] [[1, 'He also bought two bulletproof vests']]
# New stripped sentence =  [[4, 'SBab']] [] [[4, 'VBab']] [[4, 'CCab']]
# Origial sentence connotation=  [[1, 'He']] [[5, 'bulletproof'], [6, 'vests']]
# [] [[2, 'about $700 each\n']] [] [[1, 'He also bought two bulletproof vests']]
# <class 'TypeError'>
# New stripped sentence =  [[1, 'He']] [] [[2, 'could'], [4, 'find']] [[7, 'CCab']]
# Origial sentence connotation=  [[1, 'He']] [[10, 'daughter']]
# He could not find one small enough
# [] [] [] [[1, 'He could not find one small enough']]
# New stripped sentence =  [[2, 'daughter']] [] [[2, 'VBab']] [[2, 'CCab']]
# Origial sentence connotation=  [[1, 'He']] [[10, 'daughter']]
# Check daughter [[10, 'daughter']]
# [] [] [[2, 'his daughter\n']] [[1, 'He could not find one small enough']]
# <class 'TypeError'>
# New stripped sentence =  [[3, 'thing'], [4, 'I']] [] [[5, 'know']] [[5, 'CCab']]
# Origial sentence connotation=  [[3, 'thing'], [4, 'I'], [8, 'God']] [[13, 'situation']]
# The only thing I know
# [] [] [] [[1, 'The only thing I know']]
# New stripped sentence =  [[2, 'God'], [7, 'situation'], [9, 'I']] [[16, 'family']] [[4, 'were'], [10, 'will'], [11, 'be'], [12, 'left'], [14, 'defend']] [[16, 'CCab']]
# Origial sentence connotation=  [[3, 'thing'], [4, 'I'], [8, 'God']] [[13, 'situation']]
# sure God if were in a situation again I will be left to defend my family
#
# [] [] [] [[1, 'The only thing I know'], [2, 'sure God if were in a situation again I will be left to defend my family\n']]
# The only thing I know
# sure God if were in a situation again I will be left to defend my family
# New stripped sentence =  [[3, 'calls']] [] [[3, 'VBab']] [[3, 'CCab']]
# Origial sentence connotation=  [[4, 'calls'], [6, 'help'], [10, 'he']] [[12, 'he']]
# [] [[1, 'because his calls']] [] []
# New stripped sentence =  [[1, 'help'], [5, 'he'], [7, 'he'], [12, 'himself'], [15, 'risk'], [18, 'He'], [23, 'police'], [24, 'what'], [25, 'he']] [] [[2, 'were'], [3, 'going'], [6, 'said'], [8, 'decided'], [11, 'put'], [17, 'talking'], [19, 'would'], [21, 'tell'], [26, 'had'], [27, 'learned']] [[27, 'CCab']]
# Origial sentence connotation=  [[4, 'calls'], [6, 'help'], [10, 'he']] [[12, 'he']]
# help were going nowhere he said he decided not to put himself in greater risk by talking He would not tell the police what he had learned
#
# [] [[1, 'because his calls']] [] [[2, 'help were going nowhere he said he decided not to put himself in greater risk by talking He would not tell the police what he had learned\n']]
# help were going nowhere he said he decided not to put himself in greater risk by talking He would not tell the police what he had learned
# because his calls lp were going nowre said decided not to put himself in greater risk by talking He would not tell t police what had learned
# New stripped sentence =  [[1, 'I']] [] [[2, 'm'], [3, 'bending']] [[5, 'CCab']]
# Origial sentence connotation=  [[1, 'I'], [11, 'anything']] [[12, 'he']]
# Im bending over backward
# [] [] [] [[1, 'Im bending over backward']]
# New stripped sentence =  [[5, 'anything'], [6, 'he']] [] [[1, 'nobodys'], [4, 'doing'], [7, 'said']] [[7, 'CCab']]
# Origial sentence connotation=  [[1, 'I'], [11, 'anything']] [[12, 'he']]
# not nobodys even doing anything he said
# [] [] [] [[1, 'Im bending over backward'], [2, 'not nobodys even doing anything he said ']]
# Im bending over backward
# not nobodys even doing anything he said
# New stripped sentence =  [[3, 'I'], [7, 'you'], [9, 'you'], [15, 'me'], [18, 'January'], [21, 'neighborhood'], [22, 'coordination'], [23, 'officer']] [[27, 'residents'], [30, 'Betances'], [31, 'Houses']] [[2, 'am'], [4, 'going'], [6, 'help'], [10, 'ai'], [12, 'going'], [14, 'help'], [24, 'was'], [25, 'working']] [[31, 'CCab']]
# Origial sentence connotation=  [[3, 'I'], [7, 'you'], [9, 'you'], [15, 'me'], [18, 'January'], [21, 'neighborhood'], [22, 'coordination'], [23, 'officer'], [27, 'residents'], [30, 'Betances'], [31, 'Houses'], [38, 'arrests']] [[41, 'housing']]
# Why am I going to help you if you aint going to help me By last January a new neighborhood coordination officer was working with residents of the Betances Houses
# [] [] [] [[1, 'Why am I going to help you if you aint going to help me By last January a new neighborhood coordination officer was working with residents of the Betances Houses']]
# New stripped sentence =  [[6, 'arrests'], [9, 'housing'], [10, 'command'], [11, 'Inspector'], [12, 'OSullivan']] [] [[1, 'ended'], [13, 'said']] [[13, 'CCab']]
# Origial sentence connotation=  [[3, 'I'], [7, 'you'], [9, 'you'], [15, 'me'], [18, 'January'], [21, 'neighborhood'], [22, 'coordination'], [23, 'officer'], [27, 'residents'], [30, 'Betances'], [31, 'Houses'], [38, 'arrests']] [[41, 'housing']]
# up ended with the most arrests in his housing command Inspector OSullivan said
# [] [] [] [[1, 'Why am I going to help you if you aint going to help me By last January a new neighborhood coordination officer was working with residents of the Betances Houses'], [2, 'up ended with the most arrests in his housing command Inspector OSullivan said ']]
# Why am I going to help you if you aint going to help me By last January a new neighborhood coordination officer was working with residents of the Betances Houses
# up ended with the most arrests in his housing command Inspector OSullivan said
# New stripped sentence =  [[1, 'Chief'], [2, 'Boyce']] [[6, 'silos'], [9, 'gang']] [[3, 'said']] [[9, 'CCab']]
# Origial sentence connotation=  [[1, 'Chief'], [2, 'Boyce'], [6, 'silos'], [9, 'gang'], [11, 'narcotics'], [12, 'detectives'], [19, 'complaints'], [26, 'restructuring']] [[30, 'obstacles']]
# Chief Boyce said that the silos in which gang
# [] [] [] [[1, 'Chief Boyce said that the silos in which gang']]
# New stripped sentence =  [[1, 'narcotics'], [2, 'detectives']] [[9, 'complaints']] [[3, 'used'], [5, 'work'], [6, 'made'], [7, 'responding']] [[11, 'CCab']]
# Origial sentence connotation=  [[1, 'Chief'], [2, 'Boyce'], [6, 'silos'], [9, 'gang'], [11, 'narcotics'], [12, 'detectives'], [19, 'complaints'], [26, 'restructuring']] [[30, 'obstacles']]
# narcotics detectives used to work made responding to complaints more difficult
# [] [] [] [[1, 'Chief Boyce said that the silos in which gang'], [2, 'narcotics detectives used to work made responding to complaints more difficult']]
# New stripped sentence =  [[4, 'restructuring']] [[8, 'obstacles']] [[5, 'would'], [6, 'remove']] [[8, 'CCab']]
# Origial sentence connotation=  [[1, 'Chief'], [2, 'Boyce'], [6, 'silos'], [9, 'gang'], [11, 'narcotics'], [12, 'detectives'], [19, 'complaints'], [26, 'restructuring']] [[30, 'obstacles']]
# that the recent restructuring would remove those obstacles
#
# [] [] [] [[1, 'Chief Boyce said that the silos in which gang'], [2, 'narcotics detectives used to work made responding to complaints more difficult'], [3, 'that the recent restructuring would remove those obstacles\n']]
# Chief Boyce said that the silos in which gang
# narcotics detectives used to work made responding to complaints more difficult
# that the recent restructuring would remove those obstacles
# New stripped sentence =  [[1, 'Mr'], [2, 'Fernandezs'], [3, 'complaints']] [[8, 'arrests']] [[4, 'did'], [6, 'spur']] [[8, 'CCab']]
# Origial sentence connotation=  [[1, 'Mr'], [2, 'Fernandezs'], [3, 'complaints'], [8, 'arrests'], [11, 'men']] [[14, 'hallway']]
# Mr Fernandezs complaints did not spur any arrests
# [] [] [] [[1, 'Mr Fernandezs complaints did not spur any arrests']]
# New stripped sentence =  [[2, 'men'], [5, 'hallway']] [[10, 'year'], [12, 'shootings']] [[6, 'were'], [7, 'caught']] [[12, 'CCab']]
# Origial sentence connotation=  [[1, 'Mr'], [2, 'Fernandezs'], [3, 'complaints'], [8, 'arrests'], [11, 'men']] [[14, 'hallway']]
# two men from the hallway were caught separately this year in shootings
#
# [] [] [] [[1, 'Mr Fernandezs complaints did not spur any arrests'], [2, 'two men from the hallway were caught separately this year in shootings\n']]
# Mr Fernandezs complaints did not spur any arrests
# two men from the hallway were caught separately this year in shootings
# New stripped sentence =  [[3, 'them'], [4, 'whom'], [5, 'Mr'], [6, 'Fernandez'], [10, 'police'], [11, 'report'], [15, 'summer'], [19, 'officer'], [22, 'metal']] [[24, 'chair']] [[7, 'named'], [12, 'was'], [13, 'charged'], [17, 'hitting'], [23, 'folding']] [[24, 'CCab']]
# Origial sentence connotation=  [[3, 'them'], [4, 'whom'], [5, 'Mr'], [6, 'Fernandez'], [10, 'police'], [11, 'report'], [15, 'summer'], [19, 'officer'], [22, 'metal'], [24, 'chair'], [28, 'gunshots']] [[31, 'crowd']]
# One of them whom Mr Fernandez named in a police report was charged this summer with hitting an officer with a metal folding chair
# [] [] [] [[1, 'One of them whom Mr Fernandez named in a police report was charged this summer with hitting an officer with a metal folding chair']]
# New stripped sentence =  [[3, 'gunshots'], [6, 'crowd'], [7, 'court'], [8, 'papers']] [] [[1, 'firing'], [9, 'say']] [[9, 'CCab']]
# Origial sentence connotation=  [[3, 'them'], [4, 'whom'], [5, 'Mr'], [6, 'Fernandez'], [10, 'police'], [11, 'report'], [15, 'summer'], [19, 'officer'], [22, 'metal'], [24, 'chair'], [28, 'gunshots']] [[31, 'crowd']]
# three firing gunshots into a crowd court papers say
# [] [] [] [[1, 'One of them whom Mr Fernandez named in a police report was charged this summer with hitting an officer with a metal folding chair'], [2, 'three firing gunshots into a crowd court papers say ']]
# One of them whom Mr Fernandez named in a police report was charged this summer with hitting an officer with a metal folding chair
# three firing gunshots into a crowd court papers say
# New stripped sentence =  [] [[4, 'SBab']] [[2, 'was']] [[4, 'CCab']]
# Origial sentence connotation=  [] [[6, 'Mr'], [7, 'Fernandez']]
# [[1, 'That was too late']] [] [] []
# New stripped sentence =  [[1, 'Mr'], [2, 'Fernandez']] [] [[2, 'VBab']] [[2, 'CCab']]
# Origial sentence connotation=  [] [[6, 'Mr'], [7, 'Fernandez']]
# Check Mr [[6, 'Mr'], [7, 'Fernandez']]
# [[1, 'That was too late']] [] [[2, 'Mr Fernandez\n']] []
# <class 'TypeError'>

# %%
sen  = "I have never visited africa nor have I visited Asia"

# %%
subjlst,objlst,broke,check = rule_1(sen)

# %%
get_it_all_spacy(sen)
# Out:
# ([[1, 'I'], [5, 'africa'], [8, 'I']],
#  [[10, 'Asia']],
#  [[2, 'have'], [4, 'visited'], [7, 'have'], [9, 'visited']],
#  [[6, 'nor']])

# %%
allavail = list()
empsubjlst = list()
empobjlst = list()
empverblst = list()
onlyobjlst = list()
onlysubjlst = list()
count=0;
total = len(broke)
for i in broke:
    ## Checks all sentences of the conjunction broke sentences. 
    subj=1;
    verb=1;
    obj=1;
    count+=1
    ## The following line gets the broken sentence's predicate subject and object.
    subj2lst,obj2lst,verb2lst,cc2lst = get_it_all_spacy(i.strip())
    print("New stripped sentence = ",subj2lst,obj2lst,verb2lst,cc2lst)
    print("Origial sentence connotation= ",subjlst,objlst)
    ## if no subject: turn variable of subj 0 to denote.. no subject.
    if len(subj2lst)==0:
        subj=0
        if len(obj2lst)!=0:
            ## it is possible that object of the sentence may not be an object in the 
            ## original sentence before breaking by conjunction instead could be a subject
            ## in such case it finds the whether subject or object of original sentence
            ## and makes subj variable 1 and obj variable 0
            if any(obj2lst[0][1] in ls for ls in subjlst):
                print("Check",obj2lst[0][1],subjlst)
                subj=1
                obj=0
    if len(obj2lst)==0:
        obj=0;
        ## Similarly performs similar checking for subject of the sentence and makes 
        ## necessary variables show it. 
        if len(subj2lst)!=0:
            if any(subj2lst[0][1] in ls for ls in objlst):
                print("Check",subj2lst[0][1],objlst)
                subj=0
                obj=1
    ## If there is no verb in the sentence.. in case of dependent clauses. 
    if verb2lst[0][1]=="VBab":
        verb=0;
    if subj==0 and verb!=0 and obj!=0:
        ## empsubjlst is for the dependant clauses.. - rule 3
        empsubjlst.append([count,i])
    if subj==0 and verb==0 and obj!=0:
        ## onlyobjlst is for the independant clauses -- rule2
        onlyobjlst.append([count,i])
    if subj!=0 and verb!=0:
        ## allavail -- clauses that are simple and independent
        lstnew = list()
        if verb2lst[0][0]==1:
            lstnew = i.split()
            temp = lstnew[0]
            lstnew[0]=lstnew[1]
            lstnew[1] = temp
            i=""
            for word in lstnew:
                i+=word+ " "
        print(i)
        allavail.append([count,i])
    if subj!=0 and verb==0 and obj==0:
        ## For reverse rule 2 case where only subject exists in the dependant clause.
        onlysubjlst.append([count,i])
    print(empsubjlst,onlysubjlst,onlyobjlst,allavail)
# Check for case in Rule2 or Rule3:
if len(broke)==len(allavail):
#         fw.write("Sentence = "+sen+"\n")
    for i in allavail:
        print(re.sub(' +', ' ',i[1]).strip())
#             fw.write("\t"+re.sub(' +', ' ',i[1]).strip()+"\n") 
#         fw.write("\n-----\n")
else:
    try:
        allavail = rule_2_3(empsubjlst,allavail,onlyobjlst,onlysubjlst)
#             fw.write("Sentence = "+sen+"\n")
        for i in allavail:
            print(re.sub(r'\b(.+)\s+\1\b', r'\1', re.sub(' +', ' ',i[1]).strip()))
#                 fw.write("\t"+re.sub(r'\b(.+)\s+\1\b', r'\1', re.sub(' +', ' ',i[1]).strip())+"\n")
#             fw.write("\n-----\n")
    except:
#             fw.write("Sentence = "+sen+"\n")
        print(sys.exc_info()[0])
#             fw.write("\tAlready Simple\n")
#             fw.write("\n-----\n")
# Out:
# New stripped sentence =  [[1, 'I']] [[5, 'africa']] [[2, 'have'], [4, 'visited']] [[5, 'CCab']]
# Origial sentence connotation=  [[1, 'I'], [5, 'africa'], [8, 'I']] [[10, 'Asia']]
# I have never visited africa
# [] [] [] [[1, 'I have never visited africa']]
# New stripped sentence =  [[2, 'I']] [[4, 'Asia']] [[1, 'have'], [3, 'visited']] [[4, 'CCab']]
# Origial sentence connotation=  [[1, 'I'], [5, 'africa'], [8, 'I']] [[10, 'Asia']]
# I have visited Asia
# [] [] [] [[1, 'I have never visited africa'], [2, 'I have visited Asia ']]
# I have never visited africa
# I have visited Asia
